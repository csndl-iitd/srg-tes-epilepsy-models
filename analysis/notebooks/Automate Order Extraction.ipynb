# %% [markdown]
# # Automates Global Order data and Local Order data extraction
#
# 1. Extract Global Order Data
# 2. Extract Local Order Data
# 3. Store in data folder

# %%
# %reload_ext autoreload
# %autoreload 2
from tes.data_ingestion import DataRead

# %% [markdown]
# #### Create object of class DataRead

# %%
ext = DataRead()

# %% [markdown]
# #### Call ext_global_order function

# %%
l = ext.ext_global_order(4, "itr_test.bz2", "loc_test.bz2")
# Out:
# Current iteration is 0
# D:\srg_tES\srg-tes-epilepsy-models\data\connectivity_matrix\mb_communities.npz already exists
# DataUtils initialized
# 0.05106045143057527
# Current iteration is 1
# D:\srg_tES\srg-tes-epilepsy-models\data\connectivity_matrix\mb_communities.npz already exists
# DataUtils initialized
# 0.5251723886916954
# Current iteration is 2
# D:\srg_tES\srg-tes-epilepsy-models\data\connectivity_matrix\mb_communities.npz already exists
# DataUtils initialized
# 0.06462403353215974
# Current iteration is 3
# D:\srg_tES\srg-tes-epilepsy-models\data\connectivity_matrix\mb_communities.npz already exists
# DataUtils initialized
# 0.4884807459364324
# Stored Global Order data and Local order data in data folder
# Number of transitions is 2

# %% [markdown]
# #### Print list of iterations which had transitions

# %%
print(l)
# Out:
# [1, 3]

# %% [markdown]
# #### Read store simulation dataframe

# %%
ext.data_read_bz2("itr_test.bz2")
# Out:
#               0         1         2         3
# 0      0.056480  0.114353  0.008069  0.060204
# 1      0.056199  0.114642  0.008122  0.060472
# 2      0.055882  0.114837  0.008121  0.060698
# 3      0.055530  0.114939  0.008066  0.060878
# 4      0.055145  0.114948  0.007960  0.061014
# ...         ...       ...       ...       ...
# 39995  0.040241  0.526267  0.058711  0.484423
# 39996  0.043028  0.525984  0.060054  0.485450
# 39997  0.045763  0.525706  0.061495  0.486471
# 39998  0.048442  0.525436  0.063022  0.487483
# 39999  0.051060  0.525172  0.064624  0.488481
#
# [40000 rows x 4 columns]

# %% [markdown]
# #### Reading stored local order data

# %%
ext.data_read_bz2("loc_test.bz2")
# Out:
#            0         1         2         3         4         5         6     \
# 1 0    0.102846  0.105248  0.107626  0.109970  0.112270  0.114516  0.116702
#   1    0.082458  0.083418  0.084228  0.084891  0.085407  0.085779  0.086010
#   2    0.080705  0.080621  0.080435  0.080155  0.079787  0.079342  0.078827
#   3    0.215395  0.211638  0.207771  0.203799  0.199730  0.195571  0.191330
