# %%
import pickle
from scipy.stats import gaussian_kde
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
import umap

# %reload_ext autoreload
# %autoreload 2

from tes.data_ingestion import DataRead
from tes.analysis import AnalysisFunc
from tes.algo_umap import UmapAlgo
from tes.algo_partial_full import AlgoParFull
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import TwoSlopeNorm
from pathlib import Path
import glob
import statistics
import networkx as nx
import seaborn as sns
from tes.DataUtils import DataUtils
from scipy.stats import mannwhitneyu

# %%
algo_pf = AlgoParFull()
analyse = AnalysisFunc()
reader = DataRead()
algo = UmapAlgo()
utils = DataUtils()
# Out:
# ../../data/connectivity_matrix/mb_communities.npz already exists
# DataUtils initialized

# %%
df = reader.data_read_bz2("raw/FN/itr_200.bz2")

# %%
df_bla = reader.data_read_bz2("raw/BLA/itr_200.bz2")

# %%
minima = algo_pf.compute_threshold(df)
print(minima)
# Out:
# 0
# 1
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...

# %%
thres = minima.copy()

# %%
df = df_bla.copy()

# %%
n = 6
analyse.plot_global_synchrony(df[n], 0.05)

# %%
k = algo.compute_parameters(df[n])
# Out:
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
def compute_start_stop(df, embed):
    """Compute start and stop points.
    Args:
        embed (list): Contains timesteps
    Returns:
        Dictionary: Keys- 'start_points','stop_points'"""
    data = df.rolling(800, center=True).mean().ffill().bfill()

    # defining function to check if GO crosses 0.2
    def check_go(i):
        flag = False
        for val in embed[i : i + 4]:

            if data[val] > 0.2:
                flag = True

                break
            else:
                i += 1
        return flag

    def check_stop(j):

        # to compute stop
        flag_stop = False
        while j + 1 < len(embed):
            if (embed[j + 1] - embed[j]) > 400:
                flag_stop = True
                break
            else:
                j += 1
        if flag_stop == False:
            if data[embed[j]] < 0.3:
                flag_stop = True

        return [flag_stop, j]

    i = 0
    start = []
    stop = []
    while i + 4 < len(embed):

        start_dum = embed[i]
        # check if consecutively 4 embeddings appear from start point
        if (embed[i + 4] - start_dum) == 400 and check_go(i) == True:
            start.append(embed[i])
            if check_stop(i)[0] == True:
                stop.append(embed[check_stop(i)[1]])
                i = check_stop(i)[1] + 1
            else:
                break
        else:
            i += 1
    return {"start_points": start, "stop_points": stop}

# %%
compute_start_stop(df[n], embed)
# Out:
# {'start_points': [], 'stop_points': []}

# %%
k = compute_start_stop(df[n], embed)

# %%
k
# Out:
# {'start_points': [12800, 20800, 27000, 31200, 38300],
#  'stop_points': [19800, 23500, 29500, 33600]}

# %%
algo.plot_transition(df[n], k["start_points"], k["stop_points"])
# Out:
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
k
# Out:
# {'start_points': [12800, 20800, 27000, 31200, 38300],
#  'stop_points': [19800, 23500, 29500, 33600]}

# %%
start_points = k["start_points"].copy()
stop_points = k["stop_points"].copy()

# %%
algo.compute_transition_time(df[n], k["start_points"].copy())
# Out:
# 13873
# 21718
# 27855
# 31674
# [73.60000000000001, 65.85000000000001, 62.7, 43.650000000000006]

# %%
algo_pf.compute_fpt(k["start_points"].copy(), k["stop_points"].copy())
# Out:
# [640.0, 50.0, 175.0, 85.0, 235.0]

# %%
algo_pf.compute_sync(k["start_points"].copy(), k["stop_points"].copy())
# Out:
# [390.0, 175.0, 165.0, 160.0]

# %%
k
# Out:
# {'start_points': [7600, 12900, 35700], 'stop_points': [8300, 13700, 36100]}

# %%
cov = algo_pf.compute_coverage(df[n], k["start_points"].copy(), k["stop_points"].copy())

# %%
cov
# Out:
# [0.3163812610416597,
#  0.29927072572691926,
#  0.3143918647293236,
#  0.2534315686837016,
#  0.32752187319325093]

# %%
algo_pf.compute_num_trans(cov, thres)
# Out:
# {'part_ind': [0, 1, 2],
#  'full_ind': [],
#  'count_part': 3,
#  'count_full': 0,
#  'count_trans': 3}

# %%
data = df.iloc[:, 0:7]
data
# Out:
#               0         1         2         3         4         5         6
# 0      0.022092  0.052095  0.058786  0.015426  0.018858  0.068035  0.047011
# 1      0.022854  0.053056  0.059288  0.013727  0.016354  0.070249  0.046485
# 2      0.023662  0.053991  0.059798  0.012071  0.013891  0.072384  0.045958
# 3      0.024510  0.054898  0.060316  0.010490  0.011512  0.074438  0.045436
# 4      0.025393  0.055774  0.060842  0.009035  0.009297  0.076406  0.044923
# ...         ...       ...       ...       ...       ...       ...       ...
# 39995  0.090792  0.134878  0.050954  0.533073  0.049910  0.055649  0.405209
# 39996  0.091130  0.136742  0.051073  0.534261  0.049928  0.055121  0.403762
# 39997  0.091431  0.138595  0.051097  0.535436  0.049922  0.054656  0.402258
# 39998  0.091694  0.140428  0.051025  0.536599  0.049895  0.054255  0.400699
# 39999  0.091918  0.142235  0.050854  0.537750  0.049847  0.053917  0.399087
#
# [40000 rows x 7 columns]

# %%
par = algo_pf.compute_param_df(data)
# Out:
# 0
# 37363
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 1
# 2
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...

# %%
par[0]
# Out:
# {'n_part': 10, 'n_full': 1, 'n_total': 11, 'itr_tran': [0, 2, 3, 4, 6]}

# %%
par[1]
# Out:
# {'t_t': [48.1,
#   56.1,
#   56.5,
#   61.95,
#   56.050000000000004,
#   73.60000000000001,
#   65.85000000000001,
#   62.7,
#   43.650000000000006],
#  'fp_t': [1840.0,
#   325.0,
#   810.0,
#   550.0,
#   1345.0,
#   640.0,
#   50.0,
#   175.0,
#   85.0,
#   235.0],
#  's_t': [70.0, 95.0, 130.0, 120.0, 0.0, 390.0, 175.0, 165.0, 160.0],
#  'cov': [0.24183387967431963,
#   0.2944367168507059,
#   0.2565365912932994,
#   0.34314968196291706,
#   0.08631286895581236,
#   0.3163812610416597,
#   0.29927072572691926,
#   0.3143918647293236,
#   0.2534315686837016,
#   0.32752187319325093]}

# %%
par[2]
# Out:
# {'t_t': [74.45], 'fp_t': [640.0], 's_t': [0.0], 'cov': [0.4418069445499282]}

# %%
par_param = par[1]
par_param.keys()
# Out:
# dict_keys(['t_t', 'fp_t', 's_t', 'cov'])

# %%
full_param = par[2]
full_param.keys()
# Out:
# dict_keys(['t_t', 'fp_t', 's_t', 'cov'])

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 8), sharex=False)

ax1.violinplot(par_param["t_t"], showmedians=True)
ax1.set_title("Transition time")
ax2.violinplot(par_param["fp_t"], showmedians=True)
ax2.set_title("FPT")
sync = [i for i in par_param["s_t"] if i != 0]
ax3.violinplot(sync, showmedians=True)
ax3.set_title("Sync State Time")
cvr = [j for j in par_param["cov"] if j != 0 and not np.isnan(j)]
ax4.violinplot(cvr, showmedians=True)
ax4.set_title("Coverage")
fig.suptitle("Partial Transitions FN (200 itr)")
# Out:
# Text(0.5, 0.98, 'Partial Transitions FN (200 itr)')

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 8), sharex=False)

ax1.violinplot(full_param["t_t"], showmedians=True)
ax1.set_title("Transition time")
ax2.violinplot(full_param["fp_t"], showmedians=True)
ax2.set_title("FPT")
sync = [i for i in full_param["s_t"] if i != 0]
ax3.violinplot(sync, showmedians=True)
ax3.set_title("Sync State Time")
cvr = [j for j in full_param["cov"] if j != 0 and not np.isnan(j)]
ax4.violinplot(cvr, showmedians=True)
ax4.set_title("Coverage")
fig.suptitle("Full Transitions FN (200 itr)")
# Out:
# Text(0.5, 0.98, 'Full Transitions FN (200 itr)')

# %% [markdown]
# ## Reading BLA data

# %%
df_bla = reader.data_read_bz2("raw/BLA/itr_200.bz2")

# %%
bla_par = algo_pf.compute_param_df(df_bla)
# Out:
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# ...

# %%
 print(l_embed)
        start=[]
        stop=[]
        
        if len(l_embed)!=0:
            start=[l_embed[0]]
            
            ind=0
            while ind<len(l_embed)-1:
                
                if l_embed[ind+1]-l_embed[ind] >400:
                    stop.append(l_embed[ind])
                    start.append(l_embed[ind+1])
                    
                ind+=1
            print(start)
            print(stop)
            # for adding start point
            if len(start)!=0:
                print(f'start {start}')
                if l_embed[-1]-start[-1]<400: 
                    start.pop(-1)       
            
            #for adding stop points if it falls
            if len(start)!=0:
                if l_embed[-1]-start[-1] > 400:
                    stop.append(l_embed[-1])
                    if len(start)!=len(stop):
                        stop.pop(-1)
            
            # Ignoring where GO never crosses 0.2 and length > 400 
            for _start,_stop in zip(start,stop):
                val=[]
                for r in range(_start,_stop,100): 
                    val.append(_data[r])
                    
                if _stop-_start<=400 or r<=0.2: 
                    stop.remove(_stop)
                    start.remove(_start)
            
            # if there is only one transition which does not fall back, remove the stop point 
            if len(stop)!=0:
                if _data[stop[-1]]>=0.3: 
                    stop.pop(-1)
    
        points_dict=dict(zip(['start_points','stop_points'],[start,stop]))
        return points_dict

# %%
bla_par[0]
# Out:
# {'n_part': 89,
#  'n_full': 56,
#  'n_total': 145,
#  'itr_tran': [0,
#   2,
#   7,
#   10,
#   12,
#   14,
#   15,
#   20,
#   21,
#   25,
#   26,
#   28,
#   30,
#   32,
#   33,
#   35,
#   36,
#   38,
#   42,
#   45,
#   46,
#   48,
#   49,
#   51,
#   53,
#   55,
#   56,
#   58,
#   62,
#   64,
#   65,
#   71,
#   72,
#   74,
#   76,
#   79,
#   81,
#   82,
#   83,
#   84,
#   87,
#   88,
#   90,
#   95,
#   96,
#   99,
#   101,
#   102,
#   103,
#   104,
#   114,
#   115,
#   118,
#   121,
#   122,
#   123,
#   129,
#   131,
#   132,
#   137,
#   139,
#   142,
#   145,
#   146,
#   147,
#   151,
#   155,
#   158,
#   160,
#   161,
#   163,
#   165,
#   167,
#   169,
#   170,
#   171,
#   173,
#   174,
#   178,
#   182,
#   186,
#   188,
#   190,
#   193,
#   196,
#   197]}

# %%
par_param = bla_par[1].copy()

# %%
full_param = bla_par[2].copy()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 8), sharex=False)

ax1.violinplot(par_param["t_t"], showmedians=True)
ax1.set_title("Transition time")
ax2.violinplot(par_param["fp_t"], showmedians=True)
ax2.set_title("FPT")
sync = [i for i in par_param["s_t"] if i != 0]
ax3.violinplot(sync, showmedians=True)
ax3.set_title("Sync State Time")
cvr = [j for j in par_param["cov"] if j != 0 and not np.isnan(j)]
ax4.violinplot(cvr, showmedians=True)
ax4.set_title("Coverage")
fig.suptitle("Partial Transitions FN (200 itr)")
# Out:
# Text(0.5, 0.98, 'Partial Transitions FN (200 itr)')

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 8), sharex=False)

ax1.violinplot(full_param["t_t"], showmedians=True)
ax1.set_title("Transition time")
ax2.violinplot(full_param["fp_t"], showmedians=True)
ax2.set_title("FPT")
sync = [i for i in full_param["s_t"] if i != 0]
ax3.violinplot(sync, showmedians=True)
ax3.set_title("Sync State Time")
cvr = [j for j in full_param["cov"] if j != 0 and not np.isnan(j)]
ax4.violinplot(cvr, showmedians=True)
ax4.set_title("Coverage")
fig.suptitle("Full Transitions BLA (200 itr)")
# Out:
# Text(0.5, 0.98, 'Full Transitions BLA (200 itr)')

# %%
reader.data_read_pkl(f"results/partial_full_data_1000_itr/{n}")
# Out:
# [12, 3, 4]

# %% [markdown]
# ### Reading data for nodes with 200 iterations

# %%
# read data of NOI
FN_folder = Path("../../data/raw/FN/")
ENTI_folder = Path("../../data/raw/ENTI/")
ORBI_folder = Path("../../data/raw/ORBI/")
PERI_folder = Path("../../data/raw/PERI/")
PIR_folder = Path("../../data/raw/PIR/")
RE_folder = Path("../../data/raw/RE/")
BLA_folder = Path("../../data/raw/BLA/")
files_nc = []
files_itr = []
folders = [
    FN_folder,
    PERI_folder,
    ENTI_folder,
    ORBI_folder,
    RE_folder,
    BLA_folder,
    PIR_folder,
]
for folder in folders:
    file_nc = glob.glob(str(folder / "nc_200.bz2"))
    files_nc.append(file_nc[0])
    file_itr = glob.glob(str(folder / "itr_200.bz2"))
    files_itr.append(file_itr[0])

# read data of connector nodes
data_folder = Path("../../data/raw/check_connector/")
connector_nc = glob.glob(str(data_folder / "nc_200*.bz2"))
connector_itr = glob.glob(str(data_folder / "itr_200*.bz2"))

# remove repeated nodes
connector_nc.pop(2)
connector_nc.pop(3)
connector_itr.pop(2)
connector_itr.pop(3)
connector_itr.pop(-1)

files_nc = files_nc + connector_nc
files_itr = files_itr + connector_itr

# read data of control nodes
data_folder = Path("../../data/raw/check_control/")
control_nc = glob.glob(str(data_folder / "nc_200*.bz2"))
control_itr = glob.glob(str(data_folder / "itr_200*.bz2"))

# remove repeated nodes
control_nc.pop(2)
control_itr.pop(2)
control_itr.pop(-1)

files_nc = files_nc + control_nc
files_itr = files_itr + control_itr
node_label = [
    "FN",
    "PERI",
    "ENTI",
    "ORB",
    "RE",
    "BLA",
    "PIR",
    "MOp",
    "MOs",
    "LHA",
    "MOB",
    "LSc",
    "MRN",
]

print(files_itr)
for label, f_itr in zip(node_label, files_itr):
    # df_nc = pd.read_pickle(f_nc, compression="bz2")
    df_itr = pd.read_pickle(f_itr, compression="bz2")

    # Calculating transition time and number of transitions
    params = algo_pf.compute_param_df(df_itr)

    reader.data_dump_pkl(f"results/partial_full_data_200_itr/{label}", params)

    print(f"{f_itr} DONE")
# Out:
# ['../../data/raw/FN/itr_200.bz2', '../../data/raw/PERI/itr_200.bz2', '../../data/raw/ENTI/itr_200.bz2', '../../data/raw/ORBI/itr_200.bz2', '../../data/raw/RE/itr_200.bz2', '../../data/raw/BLA/itr_200.bz2', '../../data/raw/PIR/itr_200.bz2', '../../data/raw/check_connector/itr_200_1.bz2', '../../data/raw/check_connector/itr_200_2.bz2', '../../data/raw/check_connector/itr_200_4.bz2', '../../data/raw/check_control/itr_200_1.bz2', '../../data/raw/check_control/itr_200_2.bz2', '../../data/raw/check_control/itr_200_4.bz2']
# /home/jupyter-nimish/env_tes/lib/python3.10/site-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.7.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# ...

# %%
node_label = [
    "FN",
    "PERI",
    "ENTI",
    "ORB",
    "RE",
    "BLA",
    "PIR",
    "MOp",
    "MOs",
    "LHA",
    "MOB",
    "LSc",
    "MRN",
]

# %%
len(node_label)
# Out:
# 13

# %%
len(files_itr)
# Out:
# 13
