# %% [markdown]
# ### Calculate the parameters Transition time, Sync time, FPT , Coverage using NC data and number of transitions
#
# #### Data folder:
# - data/raw/workstation for Global Order, Local Order and Node Community data
# - data/raw/workstation/coverage_nc for Coverage data of any network (this uses compute_coverage_nc() function in commAnalysis.py)
# - For above data, the thresholds are at results/coverage_threshold.pkl

# %% [markdown]
# #### Import necessary libraries

# %%
import numpy as np
import pandas as pd
from tes.data_ingestion import DataRead
from tes.analysis import AnalysisFunc
from tes.algo_umap import UmapAlgo
from tes.algo_partial_full import AlgoParFull
from tes.commAnalysis import CommPercentages
from tes.DataUtils import DataUtils
from scipy.stats import mannwhitneyu
from scipy.stats import spearmanr, linregress
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
from matplotlib import cm
from pathlib import Path
import os
import glob
import networkx as nx
import pwlf
import pickle
import umap

# %% [markdown]
# #### Make objects to use the functions

# %%
algo_umap = UmapAlgo()
algo= AlgoParFull()
analyse= AnalysisFunc()
reader = DataRead()
comm_ops = CommPercentages()
utils = DataUtils()
# Out:
# ..\..\data\connectivity_matrix\mb_communities.npz already exists
# DataUtils initialized

# %% [markdown]
# #### Read all data i.e  global order and node community data
# - stored in data/raw/workstation

# %%
data_folder = Path('../../data/raw/workstation')
files_go=glob.glob(str(data_folder/'tes_*_go.bz2'))
files_nc=glob.glob(str(data_folder / 'tes_*_nc.bz2'))

# %% [markdown]
# #### Read Global Order and Node community files and compute all parameters separately for partial and full transitions

# %%
networks = list(reader.data_read_pkl('results/coverage_threshold.pkl').keys())

# %%
# umcomment if you want to calculate params once again
for f_go, f_nc, nw in zip(files_go,files_nc, networks):
    # read files
    df_go = pd.read_pickle(f_go,compression='bz2')
    df_nc = pd.read_pickle(f_nc,compression='bz2')
    data = algo.compute_final_param_df(df_go,df_nc,nw)
    reader.data_dump_pkl(f'results/calculate_final_params/final_{nw}.pkl',data)
# Out:
# 0.43419537550894116
# 0
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 1
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 2
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# 3
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 4
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 5
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 6
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 7
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 8
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 9
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 10
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 11
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# 12
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 13
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 14
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 15
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 16
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 17
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 18
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 19
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 20
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 21
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 22
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 23
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 24
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# 25
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 26
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 27
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 28
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 29
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 30
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 31
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 32
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 33
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 34
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 35
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 36
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 37
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 38
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 39
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 40
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 41
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 42
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 43
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 44
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 45
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 46
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 47
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 48
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 49
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 50
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 51
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 52
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 53
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 54
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 55
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# this cell
# 56
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 57
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 58
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 59
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 60
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 61
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 62
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 63
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 64
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 65
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 66
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 67
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 68
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 69
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 70
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 71
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 72
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 73
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 74
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 75
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 76
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 77
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 78
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 79
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 80
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 81
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# 82
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 83
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 84
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 85
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 86
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 87
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 88
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 89
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 90
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 91
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 92
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 93
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 94
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 95
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 96
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 97
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 98
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 99
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 100
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 101
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 102
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 103
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 104
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 105
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 106
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 107
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 108
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 109
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 110
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 111
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 112
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 113
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 114
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 115
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 116
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 117
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 118
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 119
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 120
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 121
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 122
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 123
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 124
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 125
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 126
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 127
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 128
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 129
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 130
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 131
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 132
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 133
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 134
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 135
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 136
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 137
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 138
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 139
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 140
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 141
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 142
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 143
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 144
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 145
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 146
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 147
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 148
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 149
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 150
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 151
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 152
# ...
#   warnings.warn(
# 160
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 161
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 162
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 163
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 164
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 165
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 166
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 167
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# this cell
# 168
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 169
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 170
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 171
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 172
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 173
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 174
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 175
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 176
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 177
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 178
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 179
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 180
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 181
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 182
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 183
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 184
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 185
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 186
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 187
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 188
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 189
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 190
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 191
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 192
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 193
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 194
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 195
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 196
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 197
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 198
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# 199
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# done

# %% [markdown]
# #### Calculating centrality values of nodes of interest

# %%
control_node = [251, 38, 71, 284, 1, 214, 149, 362]
control_name = ["MOB", "LSc", "MOp", "MRN"]
connector_node = [214, 1, 215, 2, 249, 36, 137, 350, 53, 266]
connector_name = ["MOp", "MOs", "PERI", "LHA", "ENTI"]
imp_nodes = [36, 249, 53, 266, 23, 236, 113, 326, 64, 277, 43, 256]
imp_name = ["PERI", "ENTI", "ORB", "RE", "BLA", "PIR"]

nodes = [
    36,
    249,
    53,
    266,
    23,
    236,
    113,
    326,
    64,
    277,
    43,
    256,
    214,
    1,
    215,
    2,
    137,
    350,
    251,
    38,
    71,
    284,
    149,
    362,
]

# node labels for above
node_label = [
    "peri",
    "enti",
    "orb",
    "re",
    "bla",
    "pir",
    "mop",
    "mos",
    "lha",
    "mob",
    "lsc",
    "mrn",
    "fn"
]

# %% [markdown]
# Calculate centrality values for above nodes and arrange in dataframe

# %%
G = nx.from_numpy_array(utils.WHOLE_BRAIN_CONN)
bet_cent = nx.betweenness_centrality(G)
deg_cent = nx.degree_centrality(G)
eig_cent = nx.eigenvector_centrality(G)
efficiency = {}
for node in G.nodes:
    # Calculate the sum of reciprocal of shortest path lengths from the node to all other nodes
    sp_lengths = nx.shortest_path_length(G, source=node)
    sum_reciprocal_sp = sum(1 / length for length in sp_lengths.values() if length > 0)

    # Calculate efficiency: E(v) = (1 / (N-1)) * sum(1 / d(v, u))
    # where N is the number of nodes and d(v, u) is the shortest path length between v and u
    efficiency[node] = sum_reciprocal_sp / (len(G.nodes) - 1)


bc_vals = []
deg_vals = []
ev_vals = []
ne_vals = []

for i in nodes:
    bc_vals.append(bet_cent[i])
    deg_vals.append(deg_cent[i])
    ev_vals.append(eig_cent[i])
    ne_vals.append(efficiency[i])

print(f"Betweenness centrality values: {bc_vals}")
print(f"Degree centrality values: {deg_vals}")
print(f"Eigen vector centrality values: {ev_vals}")
print(f"Nodal Efficiency values: {ne_vals}")
# Out:
# Betweenness centrality values: [0.018279655930717145, 0.018279655930717127, 0.015142250584322597, 0.015142250584322609, 0.0006490876667139932, 0.0006490876667139933, 0.01006672083950362, 0.010066720839503631, 0.0035324020639247587, 0.0035324020639247566, 0.001820790434177627, 0.0018207904341776264, 0.024213330492729394, 0.024213330492729373, 0.020510702767149596, 0.020510702767149613, 0.021876077588668236, 0.021876077588668195, 5.380812051561027e-06, 5.380812051561027e-06, 3.1673671682144285e-05, 3.1673671682144285e-05, 0.008944551377672819, 0.008944551377672819]
# Degree centrality values: [0.27999999999999997, 0.27999999999999997, 0.2564705882352941, 0.2564705882352941, 0.09411764705882353, 0.09411764705882353, 0.21411764705882352, 0.21411764705882352, 0.16941176470588235, 0.16941176470588235, 0.10352941176470587, 0.10352941176470587, 0.3364705882352941, 0.3364705882352941, 0.3035294117647059, 0.3035294117647059, 0.30117647058823527, 0.30117647058823527, 0.018823529411764704, 0.018823529411764704, 0.018823529411764704, 0.018823529411764704, 0.24235294117647058, 0.24235294117647058]
# Eigen vector centrality values: [0.09845643218883879, 0.09845643218883875, 0.07504062905348564, 0.07504062905348566, 0.04179789513478019, 0.041797895134780175, 0.08379518836363585, 0.08379518836363585, 0.05775382101866677, 0.05775382101866678, 0.032897255593006575, 0.032897255593006575, 0.12490657184133652, 0.12490657184133656, 0.12461591750366718, 0.12461591750366717, 0.1204572429417277, 0.12045724294172769, 0.0026779274133759685, 0.0026779274133759685, 0.006186259511599863, 0.006186259511599861, 0.10986460834840547, 0.10986460834840545]
# Nodal Efficiency values: [0.6274509803921557, 0.6274509803921557, 0.6050980392156873, 0.6050980392156873, 0.5145098039215705, 0.5145098039215705, 0.5956862745098046, 0.5956862745098046, 0.5592156862745112, 0.5592156862745112, 0.5133333333333354, 0.5133333333333354, 0.656470588235293, 0.656470588235293, 0.6462745098039212, 0.6462745098039212, 0.6462745098039213, 0.6462745098039213, 0.36647058823529344, 0.36647058823529344, 0.4166666666666689, 0.4166666666666689, 0.6152941176470581, 0.6152941176470581]

# %%
# removing duplicate data from centrality values so that length matches
def dup_cent_rem(cent):
    j = 0
    val = []
    while j < len(cent):
        val.append(cent[j])
        j += 2

    return val

# z scoring all values
b_d = dup_cent_rem(bc_vals)
b = [(x - np.mean(b_d)) / np.std(b_d) for x in b_d]
b.append(0)

n_d = dup_cent_rem(ne_vals)
n = [(x - np.mean(n_d)) / np.std(n_d) for x in n_d]
n.append(0)

d_d = dup_cent_rem(deg_vals)
d = [(x - np.mean(d_d)) / np.std(d_d) for x in d_d]
d.append(0)

e_d = dup_cent_rem(ev_vals)
e = [(x - np.mean(e_d)) / np.std(e_d) for x in e_d]
e.append(0)

df_cent = pd.DataFrame(
    {"BET_CENT": b, "NOD_EFF": n, "DEG_CENT": d, "EIG_CENT": e}, index=node_label
)

df_bc = df_cent.sort_values("BET_CENT", ascending=True, inplace=False)
df_bc = df_bc.drop("fn")
print(df_bc)
# Out:
#       BET_CENT   NOD_EFF  DEG_CENT  EIG_CENT
# mob  -1.175187 -2.189893 -1.642223 -1.648583
# lsc  -1.172221 -1.632162 -1.642223 -1.566574
# orb  -1.102570 -0.545022 -0.939980 -0.734136
# pir  -0.970389 -0.558094 -0.852200 -0.942192
# bla  -0.777301 -0.048293 -0.237738 -0.361159
# mrn  -0.166753  0.574797  0.442559  0.856955
# re   -0.040160  0.356933  0.179218  0.247571
# enti  0.532414  0.461508  0.574229  0.042929
# peri  0.886346  0.709872  0.793680  0.590284
# mos   1.138032  0.919021  1.013131  1.201774
# lha   1.292061  0.919021  0.991186  1.104563
# mop   1.555728  1.032311  1.320362  1.208568

# %% [markdown]
# Add FN row so that it becomes easier to plot
# Move FN row to top so that we can plot consistently with other data

# %%
df_cent.loc["fn"] = [np.NaN] * 4
df_cent.sort_values("BET_CENT", ascending=True, inplace=True)
a = df_cent.loc[["fn"]]
df_centrality = pd.concat([a, df_bc])
df_centrality
# Out:
#       BET_CENT   NOD_EFF  DEG_CENT  EIG_CENT
# fn         NaN       NaN       NaN       NaN
# mob  -1.175187 -2.189893 -1.642223 -1.648583
# lsc  -1.172221 -1.632162 -1.642223 -1.566574
# orb  -1.102570 -0.545022 -0.939980 -0.734136
# pir  -0.970389 -0.558094 -0.852200 -0.942192
# bla  -0.777301 -0.048293 -0.237738 -0.361159
# mrn  -0.166753  0.574797  0.442559  0.856955
# re   -0.040160  0.356933  0.179218  0.247571
# enti  0.532414  0.461508  0.574229  0.042929
# peri  0.886346  0.709872  0.793680  0.590284
# mos   1.138032  0.919021  1.013131  1.201774
# lha   1.292061  0.919021  0.991186  1.104563
# mop   1.555728  1.032311  1.320362  1.208568

# %% [markdown]
# Above results are stored in folder '../../data/results/calculate_final_params/final_{nw}.pkl'
# - nw = ['bla', 'enti', 'fn', 'lha', 'lsc', 'mob', 'mop', 'mos', 'mrn', 'orb', 'peri', 'pir', 're']
# - It is stored as a pickle file which is actually a tuple
# - Tuple:
# index 0: dictionary with number of partial, full and total transition and iteration numbers with transitions
#         KEYS: ['n_part', 'n_full', 'n_total', 'itr_tran']
# index 1: partial transitions - KEY: ['t_t', 'fp_t', 's_t', 'cov']
# index 2: full transitions - KEYS: ['t_t', 'fp_t', 's_t', 'cov']

# %% [markdown]
# #### Read params for each network from pickle files and plot fig 4 (in manuscript)

# %%
# defining dictionaries for each parameter
# storing both partial and full transition data
# store standard deviation and manWhitney U test values

num_trans = {}
n_p = []
n_p_s = []
n_f = []
n_f_s = []

trans_time = {}
t_p = []
t_p_s = []
t_f = []
t_f_s = []
t_p_mw = []
t_f_mw = []

fp_time = {}
f_p = []
f_p_s = []
f_f = []
f_f_s = []
f_p_mw = []
f_f_mw = []

sync_time = {}
s_p = []
s_p_s = []
s_f = []
s_f_s = []
s_p_mw = []
s_f_mw = []

cov = {}
cov_p = []
cov_p_s = []
cov_f = []
cov_f_s = []
cov_p_mw = []
cov_f_mw = []

# node_label=['PERI','ENTI','ORB','RE','BLA','PIR','MOp','MOs','LHA','MOB','LSc','MRN']
# getting networks in ascending order
network_asc = [
    "fn",
    "mob",
    "lsc",
    "orb",
    "pir",
    "bla",
    "mrn",
    "re",
    "enti",
    "peri",
    "mos",
    "lha",
    "mop",
]
fn_data = reader.data_read_pkl("results/calculate_final_params/final_fn.pkl")

for nw in network_asc:
    params = reader.data_read_pkl(f"results/calculate_final_params/final_{nw}.pkl")
    # store number of transition
    n_p.append(params[0]["n_part"])
    n_f.append(params[0]["n_full"])
    n_p_s.append(np.sqrt(params[0]["n_part"]))
    n_f_s.append(np.sqrt(params[0]["n_full"]))

    # store transition time
    t_p_s.append(np.std(params[1]["t_t"]) / np.sqrt(len(params[1]["t_t"])))
    t_f_s.append(np.std(params[2]["t_t"]) / np.sqrt(len(params[2]["t_t"])))

    t_p.append(np.mean(params[1]["t_t"]))
    _, mw = mannwhitneyu(fn_data[1]["t_t"], params[1]["t_t"])
    t_p_mw.append(mw)
    t_f.append(np.mean(params[2]["t_t"]))
    _, mw = mannwhitneyu(fn_data[2]["t_t"], params[2]["t_t"])
    t_f_mw.append(mw)

    # store first passage time
    f_p_s.append(np.std(params[1]["fp_t"]) / np.sqrt(len(params[1]["fp_t"])))
    f_f_s.append(np.std(params[2]["fp_t"]) / np.sqrt(len(params[2]["fp_t"])))

    f_p.append(np.mean(params[1]["fp_t"]))
    _, mw = mannwhitneyu(fn_data[1]["fp_t"], params[1]["fp_t"])
    f_p_mw.append(mw)
    f_f.append(np.mean(params[2]["fp_t"]))
    _, mw = mannwhitneyu(fn_data[2]["fp_t"], params[2]["fp_t"])
    f_f_mw.append(mw)

    # Store sync time
    s_p_s.append(np.std(params[1]["s_t"]) / np.sqrt(len(params[1]["s_t"])))
    s_f_s.append(np.std(params[2]["s_t"]) / np.sqrt(len(params[2]["s_t"])))

    s_p.append(np.mean(params[1]["s_t"]))
    _, mw = mannwhitneyu(fn_data[1]["s_t"], params[1]["s_t"])
    s_p_mw.append(mw)
    s_f.append(np.mean(params[2]["s_t"]))
    _, mw = mannwhitneyu(fn_data[2]["s_t"], params[2]["s_t"])
    s_f_mw.append(mw)

    # store coverage
    # removing zero coverage values from partial transitions as they might seep due to very small values
    cov_part=params[1]["cov"]
    cov_part=[x for x in cov_part if x>0]
    cov_p_s.append(np.std(cov_part) / np.sqrt(len(cov_part)))
    cov_f_s.append(np.std(params[2]["cov"]) / np.sqrt(len(params[2]["cov"])))

    cov_p.append(np.mean(cov_part))
    _, mw = mannwhitneyu(fn_data[1]["cov"], cov_part)
    cov_p_mw.append(mw)
    cov_f.append(np.mean(params[2]["cov"]))
    _, mw = mannwhitneyu(fn_data[2]["cov"], params[2]["cov"])
    cov_f_mw.append(mw)

num_trans = {"n_p": n_p, "n_f": n_f, "n_p_s": n_p_s, "n_f_s": n_f_s}
trans_time = {
    "t_p": t_p,
    "t_f": t_f,
    "t_p_s": t_p_s,
    "t_f_s": t_f_s,
    "t_p_mw": t_p_mw,
    "t_f_mw": t_f_mw,
}
fp_time = {
    "f_p": f_p,
    "f_f": f_f,
    "f_p_s": f_p_s,
    "f_f_s": f_f_s,
    "f_p_mw": f_p_mw,
    "f_f_mw": f_f_mw,
}

sync_time = {
    "s_p": s_p,
    "s_f": s_f,
    "s_p_s": s_p_s,
    "s_f_s": s_f_s,
    "s_p_mw": s_p_mw,
    "s_f_mw": s_f_mw,
}

cov = {
    "cov_p": cov_p,
    "cov_f": cov_f,
    "cov_p_s": cov_p_s,
    "cov_f_s": cov_f_s,
    "cov_p_mw": cov_p_mw,
    "cov_f_mw": cov_f_mw,
}

# %% [markdown]
# #### Compile above data in dataframe

# %%
a = ["num_trans"] * 2
b = ["trans_time"] * 6
c = ["fp_time"] * 6
d = ["sync_time"] * 6
e = ["cov"] * 6
upper_head = a + b + c + d + e

f = ["part", "full"]
g = ["part", "part_s", "part_mw", "full_mw", "full", "full_s"] * 4
lower_head = f + g

header = [upper_head, lower_head]
data = {
    ("num_trans", "part"): num_trans["n_p"],
    ("num_trans", "full"): num_trans["n_f"],
    ("num_trans", "part_s"): num_trans["n_p_s"],
    ("num_trans", "full_s"): num_trans["n_f_s"],
    ("trans_time", "part"): trans_time["t_p"],
    ("trans_time", "part_s"): trans_time["t_p_s"],
    ("trans_time", "part_mw"): trans_time["t_p_mw"],
    ("trans_time", "full"): trans_time["t_f"],
    ("trans_time", "full_s"): trans_time["t_f_s"],
    ("trans_time", "full_mw"): trans_time["t_p_mw"],
    ("fp_time", "part"): fp_time["f_p"],
    ("fp_time", "part_s"): fp_time["f_p_s"],
    ("fp_time", "part_mw"): fp_time["f_p_mw"],
    ("fp_time", "full"): fp_time["f_f"],
    ("fp_time", "full_s"): fp_time["f_f_s"],
    ("fp_time", "full_mw"): fp_time["f_p_mw"],
    ("sync_time", "part"): sync_time["s_p"],
    ("sync_time", "part_s"): sync_time["s_p_s"],
    ("sync_time", "part_mw"): sync_time["s_p_mw"],
    ("sync_time", "full"): sync_time["s_f"],
    ("sync_time", "full_s"): sync_time["s_f_s"],
    ("sync_time", "full_mw"): sync_time["s_p_mw"],
    ("cov", "part"): cov["cov_p"],
    ("cov", "part_s"): cov["cov_p_s"],
    ("cov", "part_mw"): cov["cov_p_mw"],
    ("cov", "full"): cov["cov_f"],
    ("cov", "full_s"): cov["cov_f_s"],
    ("cov", "full_mw"): cov["cov_f_mw"],
}

df_data = pd.DataFrame(data, index=network_asc)
df_data
# Out:
#      num_trans                            trans_time                      \
#           part full     part_s     full_s       part    part_s   part_mw
# fn         187  103  13.674794  10.148892  55.228610  1.074715  1.000000
# mob        132   94  11.489125   9.695360  54.776136  1.089552  0.945461
# lsc        187   97  13.674794   9.848858  55.529947  1.011620  0.865168
# orb        136   94  11.661904   9.695360  53.057721  1.124891  0.157965
# pir        110   67  10.488088   8.185353  54.763636  1.241981  0.522551
# bla        107   51  10.344080   7.141428  54.188318  1.117801  0.985780
# mrn        148   79  12.165525   8.888194  52.996622  0.844252  0.254302
# re         200   92  14.142136   9.591663  54.124500  0.763217  0.836102
# enti       151   57  12.288206   7.549834  53.687417  0.960022  0.481269
# peri        79   47   8.888194   6.855655  50.681013  1.257283  0.010906
# mos        186   42  13.638182   6.480741  52.103763  0.827626  0.040213
# lha        140   55  11.832160   7.416198  52.502143  0.956913  0.041488
# mop        164   72  12.806248   8.485281  51.750000  0.822852  0.036977
#
#                                      ... sync_time                         \
#            full    full_s   full_mw  ...   part_mw        full     full_s
# fn    78.146602  1.312916  1.000000  ...  1.000000  347.435897  35.331097
# mob   83.306383  1.813313  0.945461  ...  0.104380  351.034483  47.294445
# lsc   79.419588  1.289129  0.865168  ...  0.986182  311.785714  68.102203
# orb   82.572340  1.616342  0.157965  ...  0.960917  347.413793  32.158404
# pir   80.195522  1.615760  0.522551  ...  0.040085  399.047619  67.131559
# bla   80.609804  1.689315  0.985780  ...  0.610470  230.625000  28.823784
# mrn   78.601899  1.529340  0.254302  ...  0.791234  407.600000  58.272546
# re    77.778261  1.304602  0.836102  ...  0.504608  487.000000  70.648425
# enti  76.766667  1.499051  0.481269  ...  0.410884  399.722222  54.870038
# peri  79.453191  1.495899  0.010906  ...  0.006671  253.333333  28.349668
# mos   85.559524  2.795582  0.040213  ...  0.324357  268.125000  29.287603
# lha   78.384545  1.645938  0.041488  ...  0.013377  358.000000  83.694683
# mop   78.736111  1.935845  0.036977  ...  0.927616  265.400000  27.489518
#
#                      cov
#        full_mw      part    part_s part_mw      full    full_s full_mw
# fn    1.000000  0.173361  0.007830     NaN  0.556866  0.006940     NaN
# mob   0.104380  0.167642  0.008659     NaN  0.546801  0.007664     NaN
# lsc   0.986182  0.186380  0.006779     NaN  0.570075  0.006157     NaN
# orb   0.960917  0.147165  0.008332     NaN  0.526395  0.008266     NaN
# pir   0.040085  0.167115  0.009095     NaN  0.540389  0.008939     NaN
# bla   0.610470  0.199997  0.010300     NaN  0.582879  0.008483     NaN
# mrn   0.791234  0.172446  0.007612     NaN  0.518023  0.008323     NaN
# re    0.504608  0.189600  0.007044     NaN  0.546913  0.007366     NaN
# enti  0.410884  0.172499  0.007728     NaN  0.556293  0.008835     NaN
# peri  0.006671  0.155180  0.010715     NaN  0.570277  0.009150     NaN
# mos   0.324357  0.156893  0.007194     NaN  0.558530  0.010439     NaN
# lha   0.013377  0.172548  0.006927     NaN  0.514550  0.009643     NaN
# mop   0.927616  0.150628  0.007123     NaN  0.536189  0.007992     NaN
#
# [13 rows x 28 columns]

# %% [markdown]
# - To access data for any network from above dataframe

# %%
df_data[("sync_time","part")].loc['fn']
# Out:
# 123.2

# %% [markdown]
# Make copy of above data to use it safely..

# %%
df=df_data.copy()

# %% [markdown]
# Define scatter plot function to plot scatter plots between centrality and parameters mean

# %%
df_sc =df.drop('fn')

# %%
df_sc
# Out:
#      num_trans                           trans_time                      \
#           part full     part_s    full_s       part    part_s   part_mw
# mob        132   94  11.489125  9.695360  54.776136  1.089552  0.945461
# lsc        187   97  13.674794  9.848858  55.529947  1.011620  0.865168
# orb        136   94  11.661904  9.695360  53.057721  1.124891  0.157965
# pir        110   67  10.488088  8.185353  54.763636  1.241981  0.522551
# bla        107   51  10.344080  7.141428  54.188318  1.117801  0.985780
# mrn        148   79  12.165525  8.888194  52.996622  0.844252  0.254302
# re         200   92  14.142136  9.591663  54.124500  0.763217  0.836102
# enti       151   57  12.288206  7.549834  53.687417  0.960022  0.481269
# peri        79   47   8.888194  6.855655  50.681013  1.257283  0.010906
# mos        186   42  13.638182  6.480741  52.103763  0.827626  0.040213
# lha        140   55  11.832160  7.416198  52.502143  0.956913  0.041488
# mop        164   72  12.806248  8.485281  51.750000  0.822852  0.036977
#
#                                      ... sync_time                         \
#            full    full_s   full_mw  ...   part_mw        full     full_s
# mob   83.306383  1.813313  0.945461  ...  0.104380  351.034483  47.294445
# lsc   79.419588  1.289129  0.865168  ...  0.986182  311.785714  68.102203
# orb   82.572340  1.616342  0.157965  ...  0.960917  347.413793  32.158404
# pir   80.195522  1.615760  0.522551  ...  0.040085  399.047619  67.131559
# bla   80.609804  1.689315  0.985780  ...  0.610470  230.625000  28.823784
# mrn   78.601899  1.529340  0.254302  ...  0.791234  407.600000  58.272546
# re    77.778261  1.304602  0.836102  ...  0.504608  487.000000  70.648425
# enti  76.766667  1.499051  0.481269  ...  0.410884  399.722222  54.870038
# peri  79.453191  1.495899  0.010906  ...  0.006671  253.333333  28.349668
# mos   85.559524  2.795582  0.040213  ...  0.324357  268.125000  29.287603
# lha   78.384545  1.645938  0.041488  ...  0.013377  358.000000  83.694683
# mop   78.736111  1.935845  0.036977  ...  0.927616  265.400000  27.489518
#
#                      cov
#        full_mw      part    part_s part_mw      full    full_s full_mw
# mob   0.104380  0.167642  0.008659     NaN  0.546801  0.007664     NaN
# lsc   0.986182  0.186380  0.006779     NaN  0.570075  0.006157     NaN
# orb   0.960917  0.147165  0.008332     NaN  0.526395  0.008266     NaN
# pir   0.040085  0.167115  0.009095     NaN  0.540389  0.008939     NaN
# bla   0.610470  0.199997  0.010300     NaN  0.582879  0.008483     NaN
# mrn   0.791234  0.172446  0.007612     NaN  0.518023  0.008323     NaN
# re    0.504608  0.189600  0.007044     NaN  0.546913  0.007366     NaN
# enti  0.410884  0.172499  0.007728     NaN  0.556293  0.008835     NaN
# peri  0.006671  0.155180  0.010715     NaN  0.570277  0.009150     NaN
# mos   0.324357  0.156893  0.007194     NaN  0.558530  0.010439     NaN
# lha   0.013377  0.172548  0.006927     NaN  0.514550  0.009643     NaN
# mop   0.927616  0.150628  0.007123     NaN  0.536189  0.007992     NaN
#
# [12 rows x 28 columns]

# %%
def fig_3_scatter(ax, parameter, ang_f, ang_p):

    full_vals = df_sc[(f"{parameter}", "full")]
    part_vals = df_sc[(f"{parameter}", "part")]

    x = df_bc["BET_CENT"]

    # --- Scatter plots ---
    ax.scatter(x, full_vals, c="purple", s=3, alpha=0.4)
    ax.scatter(x, part_vals, c="orange", s=3, alpha=0.4)

    # --- Full regression ---
    slope, intercept, _, _, _ = linregress(x, full_vals)
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept
    ax.plot(
        x_line, y_line, color="purple", linestyle="--", label="Full fit", linewidth=0.5
    )

    # Spearman correlation
    rho, pval = spearmanr(x, full_vals)
    mid_idx = len(x_line) // 2
    x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
    angle = np.degrees(np.arctan(slope)) + ang_f
    ax.text(
        x_mid,
        y_mid + 0.05 * (full_vals.max() - full_vals.min()),
        f"ρ={rho:.2f}, p={pval:.2g}",
        fontsize=4,
        color="purple",
        ha="center",
        rotation=angle,
        rotation_mode="anchor",
    )

    # --- Part regression ---
    slope, intercept, _, _, _ = linregress(x, part_vals)
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept
    ax.plot(
        x_line, y_line, color="orange", linestyle="--", label="Part fit", linewidth=0.5
    )

    # Spearman correlation
    rho, pval = spearmanr(x, part_vals)
    mid_idx = len(x_line) // 2
    x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
    angle = np.degrees(np.arctan(slope)) + ang_p
    ax.text(
        x_mid,
        y_mid + 0.05 * (part_vals.max() - part_vals.min()),
        f"ρ={rho:.2f}, p={pval:.2g}",
        fontsize=4,
        color="orange",
        ha="center",
        rotation=angle,
        rotation_mode="anchor",
    )

    # --- Labels and layout ---
    # ax.set_xlabel("BET_CENT")
    # ax.set_ylabel(f"{parameter}")
    # ax.legend()

# %% [markdown]
# Define function to plot bar plots for parameters so that we can compare

# %%
def fig_3_bar(ax, parameter):
    # Extract values
    full_vals = df[(f"{parameter}", "full")]
    part_vals = df[(f"{parameter}", "part")]
    full_err = df[(f"{parameter}", "full_s")]
    part_err = df[(f"{parameter}", "part_s")]
    part_mw = df[(f"{parameter}", "part_mw")]
    full_mw = df[(f"{parameter}", "full_mw")]
    # X locations
    x = np.arange(len(df.index))  # one per method
    width = 0.2  # bar width

    # control_name=['MOB','LSc','MOp','MRN']
    # connector_node=[214,1,215,2,249,36,137,350,53,266]
    # connector_name=['MOp','MOs','PERI','LHA','ENTI']
    # imp_nodes=[36,249,53,266,23,236,113,326,64,277,43,256]
    # imp_name=['PERI','ENTI','ORB','RE','BLA','PIR']

    # --- Plot bars individually with alpha based on p-value ---
    for i, idx in enumerate(df.index):
        # alpha logic: darker if significant
        alpha_full = 0.4 if full_mw.iloc[i] > 0.05 else 1.0
        alpha_part = 0.4 if part_mw.iloc[i] > 0.05 else 1.0

        ax.bar(
            x[i] - width / 2,
            full_vals.iloc[i],
            width,
            yerr=full_err.iloc[i],
            color="purple",
            alpha=alpha_full,
            error_kw={
                "elinewidth": 0.3,  # thickness of error bar line
                "capsize": 0.5,  # horizontal cap length
                "capthick": 0.3,
            },
        )  # thickness of the cap lines)

        ax.bar(
            x[i] + width / 2,
            part_vals.iloc[i],
            width,
            yerr=part_err.iloc[i],
            color="orange",
            alpha=alpha_part,
            error_kw={
                "elinewidth": 0.3,  # thickness of error bar line
                "capsize": 0.5,  # horizontal cap length
                "capthick": 0.3,
            },
        )  # thickness of the cap lines)

    # Formatting
    ax.set_ylabel(f"{parameter}")
    # ax.set_xticks(x)
    # ax.set_xticklabels(df.index, rotation=45, ha="right")
    # for label in ax.get_xticklabels():
    #     text = label.get_text()
    #     if text in control_name:
    #         label.set_color('blue')
    #     elif text in connector_name:
    #         label.set_color('green')
    #     elif text in imp_name:
    #         label.set_color('red')
    #     else:
    #         label.set_color('black')

    # ax.legend(["Full", "Part"])

# %% [markdown]
# Define function specifically for parameter 'Number of Transitions'

# %%
def fig_3_bar_num_trans(ax, parameter):
    # Extract values
    full_vals = df[(f"{parameter}", "full")]
    part_vals = df[(f"{parameter}", "part")]
    full_err = df[(f"{parameter}", "full_s")]
    part_err = df[(f"{parameter}", "part_s")]
    part_mw = 0.06
    full_mw = 0.06
    # X locations
    x = np.arange(len(df.index))  # one per method
    width = 0.2  # bar width

    # --- Plot bars individually with alpha based on p-value ---
    for i, idx in enumerate(df.index):
        # alpha logic: lighter if significant
        alpha_full = 1
        alpha_part = 1

        ax.bar(
            x[i] - width / 2,
            full_vals.iloc[i],
            width,
            yerr=full_err.iloc[i],
            color="purple",
            alpha=alpha_full,
            error_kw={
                "elinewidth": 0.3,  # thickness of error bar line
                "capsize": 0.5,  # horizontal cap length
                "capthick": 0.3,
            },
        )

        ax.bar(
            x[i] + width / 2,
            part_vals.iloc[i],
            width,
            yerr=part_err.iloc[i],
            color="orange",
            alpha=alpha_part,
            error_kw={
                "elinewidth": 0.3,  # thickness of error bar line
                "capsize": 0.5,  # horizontal cap length
                "capthick": 0.3,
            },
        )

    # Formatting
    ax.set_ylabel(f"{parameter}")
    ax.set_xticks(x)
    ax.set_xticklabels(df.index, rotation=45, ha="right")
    # ax.legend(["Full", "Part"])

# %% [markdown]
# Final figure which compare all parameters

# %%
# fig,((ax1,ax01),(ax2,ax02),(ax3,ax03),(ax4,ax04),(ax5,ax05),(ax6,ax06))=plt.subplots(6,2,figsize=([3.5,8]),sharex='col',sharey='row')
# parameters=['trans_time','fp_time','sync_time','cov']
fig = plt.figure(figsize=([3.5, 8]))
gs = gridspec.GridSpec(12, 6)
ax1 = fig.add_subplot(gs[0:2, 0:4])
ax01 = fig.add_subplot(gs[0:2, 4:6])  # share x with ax1’s column
ax6 = fig.add_subplot(gs[10:12, 0:4])
ax2 = fig.add_subplot(gs[2:4, 0:4], sharex=ax6)
ax02 = fig.add_subplot(gs[2:4, 4:6], sharey=ax2)
ax3 = fig.add_subplot(gs[4:6, 0:4], sharex=ax6)
ax03 = fig.add_subplot(gs[4:6, 4:6], sharey=ax3)
ax4 = fig.add_subplot(gs[6:8, 0:4], sharex=ax6)
ax04 = fig.add_subplot(gs[6:8, 4:6], sharey=ax4)
ax5 = fig.add_subplot(gs[8:10, 0:4], sharex=ax6)
ax05 = fig.add_subplot(gs[8:10, 4:6], sharey=ax5)

ax06 = fig.add_subplot(gs[10:12, 4:6], sharey=ax6)


plt.subplots_adjust(hspace=0.5, wspace=0.5)  # increase vertical space between rows

# Plot each centrality metric starting from MOB
# Define your custom color set (one per column)
colors = ["cyan", "blue", "green", "magenta"]
# You can use hex codes, named colors, or RGB tuples

for col, color in zip(df_centrality.columns, colors):
    series = df_centrality[col]
    ax1.plot(
        series.index,
        series,
        marker="o",
        markersize=0.5,
        linewidth=0.3,
        label=col,
        color=color,
    )
    # Add cross for NaNs (use same color or fixed red/white)
    ax1.scatter(
        series.index[series.isna()],
        [0] * series.isna().sum(),
        color="white",
        marker="x",
        zorder=5,
    )


ax1.set_ylabel("centrality \n metrics", fontsize=8)
ax1.legend(loc="lower right", fontsize=5, frameon=False)


ax01.scatter(df["num_trans", "full"], df[("num_trans", "part")], s=3)
ax01.set_xlabel("full transition", fontsize=8, color="purple")
ax01.set_ylabel("partial transition", fontsize=8, color="orange")


# x=df[('num_trans','full')]
# part_vals=df[('num_trans','part')]
# slope, intercept, _, _, _ = linregress(x, part_vals)
# x_line = np.linspace(x.min(), x.max(), 100)
# y_line = slope * x_line + intercept
# ax01.plot(x_line, y_line, color="blue", linestyle="--", label="Part fit",linewidth=0.5)

# # Spearman correlation
# rho, pval = spearmanr(x, part_vals)
# mid_idx = len(x_line) // 2
# x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
# angle = np.degrees(np.arctan(slope)) + 10
# ax01.text(x_mid, y_mid + 0.05*(part_vals.max()-part_vals.min()),
#         f"ρ={rho:.2f}, p={pval:.2g}",
#         fontsize=4, color="blue", ha="center",
#         rotation=angle, rotation_mode="anchor")


# ax01.set_ylabel('number of partial transition')
x = df["num_trans", "full"]


fig_3_bar_num_trans(ax6, "num_trans")
ax6.set_ylabel("# transitions", fontsize=8)
# ax1.legend(["Full", "Part"])
fig_3_scatter(ax06, "num_trans", 75, -75)
# ax01.legend()


fig_3_bar(ax2, "trans_time")
ax2.set_ylabel("transition time", fontsize=8)
fig_3_scatter(ax02, "trans_time", -35, -25)


fig_3_bar(ax3, "fp_time")
ax3.set_ylabel("FPT", fontsize=8)
# ax3.set_ylabel('first passage time',fontsize=8)
fig_3_scatter(ax03, "fp_time", -55, -80)


fig_3_bar(ax4, "sync_time")
ax4.set_ylabel("sync time", fontsize=8)
fig_3_scatter(ax04, "sync_time", 78, -45)


fig_3_bar(ax5, "cov")
ax5.set_ylabel("coverage", fontsize=8)
ax6.set_xlabel("names of nodes", fontsize=8)
fig_3_scatter(ax05, "cov", 0, 0)
ax06.set_xlabel("betweenness", fontsize=8)


control_name = ["MOB", "LSc", "MOp", "MRN"]
connector_node = [214, 1, 215, 2, 249, 36, 137, 350, 53, 266]
connector_name = ["MOp", "MOs", "PERI", "LHA", "ENTI"]
imp_nodes = [36, 249, 53, 266, 23, 236, 113, 326, 64, 277, 43, 256]
imp_name = ["PERI", "ENTI", "ORB", "RE", "BLA", "PIR"]

#
# plt.setp(ax1.get_yticklabels(), fontsize=8)
plt.setp(ax2.get_yticklabels(), fontsize=8)
plt.setp(ax3.get_yticklabels(), fontsize=8)
plt.setp(ax4.get_yticklabels(), fontsize=8)
plt.setp(ax5.get_yticklabels(), fontsize=8)
plt.setp(ax6.get_yticklabels(), fontsize=8)

plt.setp(ax01.get_yticklabels(), visible=False)
plt.setp(ax02.get_yticklabels(), visible=False)
plt.setp(ax03.get_yticklabels(), visible=False)
plt.setp(ax04.get_yticklabels(), visible=False)
plt.setp(ax05.get_yticklabels(), visible=False)
plt.setp(ax06.get_yticklabels(), visible=False)


plt.setp(ax01.get_xticklabels(), visible=False)
plt.setp(ax02.get_xticklabels(), visible=False)
plt.setp(ax03.get_xticklabels(), visible=False)
plt.setp(ax04.get_xticklabels(), visible=False)
plt.setp(ax05.get_xticklabels(), visible=False)

plt.setp(ax06.get_xticklabels(), fontsize=8)

# plt.setp(ax01.get_xticklabels(), visible=False)
plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax5.get_xticklabels(), visible=False)

x = np.arange(len(df.index))
ax6.set_xticks(x)
ax6.set_xticklabels(df.index, rotation=45, ha="right", fontsize=5)
for label in ax6.get_xticklabels():
    text = label.get_text()
    if text in control_name:
        label.set_color("blue")
    elif text in connector_name:
        label.set_color("green")
    elif text in imp_name:
        label.set_color("red")
    else:
        label.set_color("black")
# f.suptitle('Figure 3')
# f.tight_layout()

fig.align_labels()

fig.set_layout_engine(layout="tight")


# plt.savefig('../../data/results/figures/fig3_final.pdf',format='pdf')

# plt.savefig('../../data/results/figures/calculate_final_params_param_comparision.pdf',format='pdf')

# %% [markdown]
# #### Plot of figure 3
# - Parameters dependence on median time spent and degree

# %%
df_nc = reader.data_read_bz2("raw/workstation/tes_fn_nc.bz2")
df_itr = reader.data_read_bz2("raw/workstation/tes_fn_go.bz2")
# here G is the undirected graph
G = nx.from_numpy_array(utils.WHOLE_BRAIN_CONN)
df_r = df_nc.reset_index(drop=True)


i = 0
f = 5000
time_list = []
node_list = []
while f < df_r.shape[0]:
    l = analyse.compute_time_spent_mc(df_r.iloc[i:f, :])
    node_list.append(l)
    i = f
    f += 5000

df_time_spent = pd.DataFrame(node_list)
df_time_spent.shape

# calculate median of every column
MTS = df_time_spent.median()
med_time_spent = list(MTS)
keys = list(range(0, 426))
mts_dict = dict(zip(keys, med_time_spent))
mts_sorted = dict(sorted(mts_dict.items(), key=lambda item: item[1]))

degree = nx.degree_centrality(G)
degree_val = list(degree.values())

# %%
mts_vals = []
nodes_half = [36, 53, 23, 113, 64, 43, 1, 215, 137, 38, 71, 149]
# storing mts values
for i in nodes_half:
    mts_vals.append(mts_dict[i])
print(mts_vals)

# storing degree values
deg_vals = [degree_val[i] for i in nodes_half]
#  nodes of interest
noi = [36, 53, 23, 113, 64, 43]
noi_vals = [mts_dict[i] for i in noi]
noi_deg = [degree_val[i] for i in noi]
# connector
coi = [1, 215, 36, 137, 53]
coi_vals = [mts_dict[i] for i in coi]
coi_deg = [degree_val[i] for i in coi]
# control
cni = [38, 71, 1, 149]
cni_vals = [mts_dict[i] for i in cni]
cni_deg = [degree_val[i] for i in cni]

cn = ["ENTI", "PERI"]
cn_num = [36, 53]
cn_vals = [mts_dict[i] for i in cn_num]
cn_deg = [degree_val[i] for i in cn_num]
# Out:
# [1241.0, 958.0, 1375.0, 951.0, 1488.0, 1564.0, 64.0, 415.0, 261.0, 1776.0, 960.0, 41.0]

# %%
## defining function for scatter plots param wrt mts


def fig_4_scatter_mts(ax, parameter, ang_f, ang_p):

    x = mts_vals
    full_vals = df_sc[(f"{parameter}", "full")]
    part_vals = df_sc[(f"{parameter}", "part")]
    ax.scatter(mts_vals, full_vals, color="purple", s=3, alpha=0.5)
    ax.scatter(mts_vals, part_vals, color="orange", s=3, alpha=0.5)

    # --- Full regression ---
    x = np.asarray(x)
    slope, intercept, _, _, _ = linregress(x, full_vals)
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept
    ax.plot(
        x_line, y_line, color="purple", linestyle="--", label="Full fit", linewidth=0.5
    )

    # Spearman correlation
    rho, pval = spearmanr(x, full_vals)
    mid_idx = len(x_line) // 2
    x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
    angle = np.degrees(np.arctan(slope)) + ang_f
    ax.text(
        x_mid,
        y_mid + 0.05 * (full_vals.max() - full_vals.min()),
        f"ρ={rho:.2f}, p={pval:.2g}",
        fontsize=4,
        color="purple",
        ha="center",
        rotation=angle,
        rotation_mode="anchor",
    )

    # --- Part regression ---
    slope, intercept, _, _, _ = linregress(x, part_vals)
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept
    ax.plot(
        x_line, y_line, color="orange", linestyle="--", label="Part fit", linewidth=0.5
    )

    # Spearman correlation
    rho, pval = spearmanr(x, part_vals)
    mid_idx = len(x_line) // 2
    x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
    angle = np.degrees(np.arctan(slope)) + ang_p
    ax.text(
        x_mid,
        y_mid + 0.05 * (part_vals.max() - part_vals.min()),
        f"ρ={rho:.2f}, p={pval:.2g}",
        fontsize=4,
        color="orange",
        ha="center",
        rotation=angle,
        rotation_mode="anchor",
    )

# %%
## defining function for scatter plots param wrt degree


def fig_4_scatter_deg(ax, parameter, ang_f, ang_p):

    x = deg_vals
    full_vals = df_sc[(f"{parameter}", "full")]
    part_vals = df_sc[(f"{parameter}", "part")]
    ax.scatter(x, full_vals, color="purple", s=3, alpha=0.5)
    ax.scatter(x, part_vals, color="orange", s=3, alpha=0.5)

    # --- Full regression ---
    x = np.asarray(x)
    slope, intercept, _, _, _ = linregress(x, full_vals)
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept
    ax.plot(
        x_line, y_line, color="purple", linestyle="--", label="Full fit", linewidth=0.5
    )

    # Spearman correlation
    rho, pval = spearmanr(x, full_vals)
    mid_idx = len(x_line) // 2
    x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
    angle = np.degrees(np.arctan(slope)) + ang_f
    ax.text(
        x_mid,
        y_mid + 0.05 * (full_vals.max() - full_vals.min()),
        f"ρ={rho:.2f}, p={pval:.2g}",
        fontsize=4,
        color="purple",
        ha="center",
        rotation=angle,
        rotation_mode="anchor",
    )

    # --- Part regression ---
    slope, intercept, _, _, _ = linregress(x, part_vals)
    x_line = np.linspace(x.min(), x.max(), 100)
    y_line = slope * x_line + intercept
    ax.plot(
        x_line, y_line, color="orange", linestyle="--", label="Part fit", linewidth=0.5
    )

    # Spearman correlation
    rho, pval = spearmanr(x, part_vals)
    mid_idx = len(x_line) // 2
    x_mid, y_mid = x_line[mid_idx], y_line[mid_idx]
    angle = np.degrees(np.arctan(slope)) + ang_p
    ax.text(
        x_mid,
        y_mid + 0.05 * (part_vals.max() - part_vals.min()),
        f"ρ={rho:.2f}, p={pval:.2g}",
        fontsize=4,
        color="orange",
        ha="center",
        rotation=angle,
        rotation_mode="anchor",
    )

# %%
fig = plt.figure(figsize=(3.5, 10))
gs = gridspec.GridSpec(12, 4)

plt.subplots_adjust(hspace=0.8, wspace=0.8)
cn = ["ENTI", "PERI"]
ax1 = plt.subplot(gs[0:2, 0:4])
ax1.scatter(degree_val[0:213], med_time_spent[0:213], s=8, color=cm.Greys(0.3))
ax1.scatter(cn_deg, cn_vals, s=3, color=cm.Reds(0.8), edgecolors=cm.Greens(0.8))
ax1.scatter(noi_deg, noi_vals, s=3, color=cm.Reds(0.8), label="NOI")
ax1.scatter(coi_deg, coi_vals, s=3, color=cm.Greens(0.8), label="Connector")
ax1.scatter(cni_deg, cni_vals, s=3, color=cm.Blues(0.8), label="Control")
ax1.tick_params(axis="both", labelsize=6)

ax1.set_xlabel("degree centrality", fontsize=8)
ax1.set_ylabel("median time spent", fontsize=8)

ax6 = plt.subplot(gs[10:12, 0:2])
fig_4_scatter_mts(ax6, "cov", 0, 0)
ax6.tick_params(axis="both", labelsize=6)

ax2 = plt.subplot(gs[2:4, 0:2], sharex=ax6)
ax2.tick_params(axis="both", labelsize=6)
fig_4_scatter_mts(ax2, "trans_time", 0, 0)
ax2.set_ylabel("transition time", fontsize=8)
ax02 = plt.subplot(gs[2:4, 2:4], sharey=ax2)
fig_4_scatter_deg(ax02, "trans_time", 80, 80)

ax3 = plt.subplot(gs[4:6, 0:2], sharex=ax6)
ax3.tick_params(axis="both", labelsize=6)
fig_4_scatter_mts(ax3, "num_trans", 0, 0)
ax3.set_ylabel("# transitions", fontsize=8)
ax03 = plt.subplot(gs[4:6, 2:4], sharey=ax3)
fig_4_scatter_deg(ax03, "num_trans", -80, 80)

ax4 = plt.subplot(gs[6:8, 0:2], sharex=ax6)
ax4.tick_params(axis="both", labelsize=6)
fig_4_scatter_mts(ax4, "sync_time", 5, 5)
ax4.set_ylabel("sync time", fontsize=8)
ax04 = plt.subplot(gs[6:8, 2:4], sharey=ax4)
fig_4_scatter_deg(ax04, "sync_time", 85, 80)

ax5 = plt.subplot(gs[8:10, 0:2], sharex=ax6)
ax5.tick_params(axis="both", labelsize=6)
fig_4_scatter_mts(ax5, "fp_time", 0, -5)
ax5.set_ylabel("FPT", fontsize=8)
ax05 = plt.subplot(gs[8:10, 2:4], sharey=ax5)
fig_4_scatter_deg(ax05, "fp_time", -85, -80)


fig_4_scatter_mts(ax6, "cov", 0, 0)
ax6.set_ylabel("coverage", fontsize=8)
ax6.set_xlabel("median time spent", fontsize=8)
ax06 = plt.subplot(gs[10:12, 2:4], sharey=ax6)
fig_4_scatter_deg(ax06, "cov", 0, 0)
ax06.tick_params(axis="both", labelsize=6)
ax06.set_xlabel("degree", fontsize=8)


plt.setp(ax01.get_yticklabels(), visible=False)
plt.setp(ax02.get_yticklabels(), visible=False)
plt.setp(ax03.get_yticklabels(), visible=False)
plt.setp(ax04.get_yticklabels(), visible=False)
plt.setp(ax05.get_yticklabels(), visible=False)
plt.setp(ax06.get_yticklabels(), visible=False)


plt.setp(ax01.get_xticklabels(), visible=False)
plt.setp(ax02.get_xticklabels(), visible=False)
plt.setp(ax03.get_xticklabels(), visible=False)
plt.setp(ax04.get_xticklabels(), visible=False)
plt.setp(ax05.get_xticklabels(), visible=False)
# plt.setp(ax06.get_xticklabels(), visible=False)

plt.setp(ax1.get_xticklabels(), visible=False)
plt.setp(ax2.get_xticklabels(), visible=False)
plt.setp(ax3.get_xticklabels(), visible=False)
plt.setp(ax4.get_xticklabels(), visible=False)
plt.setp(ax5.get_xticklabels(), visible=False)
# plt.setp(ax6.get_xticklabels(), visible=False)
# plt.setp(ax5.get_xticklabels(), visible=False)
# plt.tight_layout()
# plt.savefig('fig_4.png')
fig.set_layout_engine(layout="tight")
fig.align_labels()
# plt.savefig('../../data/results/figures/fig4_final.pdf',format='pdf')

# plt.savefig("../../data/results/figures/calculate_final_param_fig3.svg")

# %% [markdown]
# #### Fit FPT and ST to 2 piecewise linear

# %% [markdown]
# Intepretation:
# - Steep slope implies faster transition
# - Slow slope implies slower transition
# - the point where slope changes is classifying that transitions which take time less and above that are different
# - ASK: can also fit 3 sometimes but ignore also the 2nd fit
# - In Part & Full fpt, we can fit 2 and it seems feasible

# %%
def fit_piecewiseLinear(data, ax, label):
    # intervals as this is the time when state changes from another state
    
    intervals = data.copy()
    # print(f'original values: {intervals}')
    intervals = np.sort(intervals)
    n = len(intervals)

    # CCDF: P(T > t)
    ccdf = 1.0 - np.arange(1, n + 1) / n

    # Remove zero values (log undefined)
    mask = ccdf > 0
    intervals = intervals[mask]
    ccdf = ccdf[mask]

    # Log of CCDF
    log_ccdf = np.log(ccdf)

    x = intervals
    y = log_ccdf

    # Fit piecewise linear model with 2 segments
    my_pwlf = pwlf.PiecewiseLinFit(x, y)
    res = my_pwlf.fit(2)

    # Breakpoints returned by pwlf.fit
    breakpoints = res   # e.g. [min_x, breakpoint, max_x]

    # First segment is between breakpoints[0] and breakpoints[1]
    # finding out interval values which contributed to slope 1
    mask_slope1 = (x >= breakpoints[0]) & (x <= breakpoints[1])
    entries_slope1 = x[mask_slope1]

    # print("Entries belonging to slope 1:", entries_slope1.tolist())
     # Entries corresponding to slope 2 (between res[1] and res[2])
    mask2 = (x >= res[1]) & (x <= res[2])
    entries_slope2 = x[mask2]

    # Predict
    y_hat = my_pwlf.predict(x)

    # Plot
    ax.scatter(x, y, label="Data")
    ax.plot(x, y_hat, 'r', label="Piecewise fit")
    ax.set_ylabel("log P(T > t)")
    ax.set_title(f"Log-CCDF breakpoint ~ {round(res[1])} {label}")
    ax.legend()

    # Slopes of the fitted lines
    slopes = my_pwlf.slopes
    print("Slopes of fitted lines:", slopes)

    # Optionally annotate slopes on the plot
    for i, slope in enumerate(slopes):
        ax.text(x.mean(), y_hat.mean() - i*0.5, f"Slope {i+1}: {slope:.3f}", color="blue")

    return {'exp':slopes, 'joint': round(res[1]),'slope_1_entries':entries_slope1.tolist(),'s2':entries_slope2.tolist()}

# %% [markdown]
# Read all data

# %%
data_folder = Path('../../data/results/calculate_final_params')
files=glob.glob(f"{data_folder}/final_*.pkl")
print(files)
# Out:
# ['..\\..\\data\\results\\calculate_final_params\\final_bla.pkl', '..\\..\\data\\results\\calculate_final_params\\final_enti.pkl', '..\\..\\data\\results\\calculate_final_params\\final_fn.pkl', '..\\..\\data\\results\\calculate_final_params\\final_lha.pkl', '..\\..\\data\\results\\calculate_final_params\\final_lsc.pkl', '..\\..\\data\\results\\calculate_final_params\\final_mob.pkl', '..\\..\\data\\results\\calculate_final_params\\final_mop.pkl', '..\\..\\data\\results\\calculate_final_params\\final_mos.pkl', '..\\..\\data\\results\\calculate_final_params\\final_mrn.pkl', '..\\..\\data\\results\\calculate_final_params\\final_orb.pkl', '..\\..\\data\\results\\calculate_final_params\\final_peri.pkl', '..\\..\\data\\results\\calculate_final_params\\final_pir.pkl', '..\\..\\data\\results\\calculate_final_params\\final_re.pkl']

# %% [markdown]
# Plot part FPT

# %%
dict_joint
# Out:
# {'bla': 397,
#  'enti': 526,
#  'fn': 504,
#  'lha': 526,
#  'lsc': 526,
#  'mob': 450,
#  'mop': 426,
#  'mos': 442,
#  'mrn': 525,
#  'orb': 498,
#  'peri': 413,
#  'pir': 446,
#  're': 497}

# %%
# Define grid size
nrows, ncols = 4, 4
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))

# Flatten axes for easy iteration
axes = axes.flatten()

# initialize as dicts instead of lists
dict_exp1 = {}
dict_exp2 = {}
dict_joint = {}
dict_slp1_vals={}

for ax, file in zip(axes, files):
    print(f'Processing file: {file}')
   
    with open(file, "rb") as f:
        params = pickle.load(f)

    part_fpt = [x for x in params[1]["fp_t"] if 20 < x < 600]

    p = fit_piecewiseLinear(part_fpt, ax, f"part_fpt_{file.split('_')[-1].split('.')[-2]}")
    nw = file.split('_')[-1].split('.')[-2]

    # directly assign into dicts
    dict_exp1[nw] = p['exp'][0]
    dict_exp2[nw] = p['exp'][1]
    dict_joint[nw] = p['joint']
    dict_slp1_vals[nw]=p['slope_1_entries']

    

plt.tight_layout()
# plt.savefig('../../data/results/Part_FPT_fit.png', format='png')
plt.show()
# Out:
# Processing file: ..\..\data\results\calculate_final_params\final_bla.pkl
# Slopes of fitted lines: [-0.00279683 -0.0167174 ]
# Processing file: ..\..\data\results\calculate_final_params\final_enti.pkl
# Slopes of fitted lines: [-0.00406948 -0.04091698]
# Processing file: ..\..\data\results\calculate_final_params\final_fn.pkl
# Slopes of fitted lines: [-0.00428927 -0.03345932]
# Processing file: ..\..\data\results\calculate_final_params\final_lha.pkl
# Slopes of fitted lines: [-0.00400748 -0.04825819]
# Processing file: ..\..\data\results\calculate_final_params\final_lsc.pkl
# Slopes of fitted lines: [-0.00473704 -0.05206954]
# Processing file: ..\..\data\results\calculate_final_params\final_mob.pkl
# Slopes of fitted lines: [-0.00383095 -0.02368881]
# Processing file: ..\..\data\results\calculate_final_params\final_mop.pkl
# Slopes of fitted lines: [-0.00450721 -0.01571485]
# Processing file: ..\..\data\results\calculate_final_params\final_mos.pkl
# Slopes of fitted lines: [-0.00418859 -0.01699749]
# Processing file: ..\..\data\results\calculate_final_params\final_mrn.pkl
# Slopes of fitted lines: [-0.00403994 -0.03047945]
# Processing file: ..\..\data\results\calculate_final_params\final_orb.pkl
# Slopes of fitted lines: [-0.0040402  -0.02943677]
# Processing file: ..\..\data\results\calculate_final_params\final_peri.pkl
# Slopes of fitted lines: [-0.00350853 -0.02669687]
# Processing file: ..\..\data\results\calculate_final_params\final_pir.pkl
# Slopes of fitted lines: [-0.00359591 -0.01565184]
# Processing file: ..\..\data\results\calculate_final_params\final_re.pkl
# Slopes of fitted lines: [-0.00421535 -0.02862008]

# %% [markdown]
# Save joint data for fig5e

# %%
part_5e=dict_joint

# %% [markdown]
#  Bar chart to compare exponents and joint

# %%
fig,ax = plt.subplots(1,3,figsize=(15,3))
# networks=list(dict_exp1.keys())
ax[0].bar(list(dict_exp1.keys()),[abs(v) for v in list(dict_exp1.values())])
ax[0].set_ylabel('-ve slope 1')
ax[1].bar(list(dict_exp2.keys()),[abs(v) for v in list(dict_exp2.values())])
ax[1].set_ylabel('-ve slope 2')
ax[2].bar(list(dict_joint.keys()),[abs(v) for v in list(dict_joint.values())])
ax[2].set_ylabel('joint')
fig.suptitle('Part FPT')
# Out:
# Text(0.5, 0.98, 'Part FPT')

# %% [markdown]
# Plot full fpt

# %%
# Define grid size
nrows, ncols = 4, 4
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))

# Flatten axes for easy iteration
axes = axes.flatten()
# initialize as dicts instead of lists
dict_exp1 = {}
dict_exp2 = {}
dict_joint = {}
dict_slp1_vals={}

for ax, file in zip(axes, files):
    print(f'Processing file: {file}')
   
    with open(file, "rb") as f:
        params = pickle.load(f)

    full_fpt = [x for x in params[2]["fp_t"] if 20 < x < 600]
    nw = file.split('_')[-1].split('.')[-2]

    p=fit_piecewiseLinear(full_fpt, ax, f'full_fpt_{nw}')

    

    # directly assign into dicts
    dict_exp1[nw] = p['exp'][0]
    dict_exp2[nw] = p['exp'][1]
    dict_joint[nw] = p['joint']
    dict_slp1_vals[nw]=p['slope_1_entries']
    

plt.tight_layout()
# plt.savefig('../../data/results/Part_FPT_fit.png', format='png')
plt.show()
# Out:
# Processing file: ..\..\data\results\calculate_final_params\final_bla.pkl
# Slopes of fitted lines: [-0.00172815 -0.01562118]
# Processing file: ..\..\data\results\calculate_final_params\final_enti.pkl
# Slopes of fitted lines: [-0.00248109 -0.01187073]
# Processing file: ..\..\data\results\calculate_final_params\final_fn.pkl
# Slopes of fitted lines: [-0.00348524 -0.02382523]
# Processing file: ..\..\data\results\calculate_final_params\final_lha.pkl
# Slopes of fitted lines: [-0.0020202  -0.01663602]
# Processing file: ..\..\data\results\calculate_final_params\final_lsc.pkl
# Slopes of fitted lines: [-0.00243662 -0.0166007 ]
# Processing file: ..\..\data\results\calculate_final_params\final_mob.pkl
# Slopes of fitted lines: [-0.00225903 -0.0156489 ]
# Processing file: ..\..\data\results\calculate_final_params\final_mop.pkl
# Slopes of fitted lines: [-0.00369442 -0.02522419]
# Processing file: ..\..\data\results\calculate_final_params\final_mos.pkl
# Slopes of fitted lines: [-0.00298575 -0.06190536]
# Processing file: ..\..\data\results\calculate_final_params\final_mrn.pkl
# Slopes of fitted lines: [-0.00313618 -0.02564854]
# Processing file: ..\..\data\results\calculate_final_params\final_orb.pkl
# Slopes of fitted lines: [-0.00304256 -0.01615882]
# Processing file: ..\..\data\results\calculate_final_params\final_peri.pkl
# Slopes of fitted lines: [-0.00103564 -0.00922595]
# Processing file: ..\..\data\results\calculate_final_params\final_pir.pkl
# Slopes of fitted lines: [-0.00201716 -0.01061981]
# Processing file: ..\..\data\results\calculate_final_params\final_re.pkl
# Slopes of fitted lines: [-0.00304838 -0.0212311 ]

# %% [markdown]
# store fpt full joints for fig5e

# %%
full_5e=dict_joint

# %%
reader.data_dump_pkl('results/figures/fig5e_data.pkl',{'part_5d':part_5e,'full_5d':full_5e})

# %% [markdown]
# Store FPT full values which corresponds to slope 1 in results folder

# %%
reader.data_dump_pkl('results/fpt_slop1_val_full.pkl',dict_slp1_vals)

# %% [markdown]
# Plot bar chart for full fpt

# %%
fig,ax = plt.subplots(1,3,figsize=(15,3))
# networks=list(dict_exp1.keys())
ax[0].bar(list(dict_exp1.keys()),[abs(v) for v in list(dict_exp1.values())])
ax[0].set_ylabel('-ve slope 1')
ax[1].bar(list(dict_exp2.keys()),[abs(v) for v in list(dict_exp2.values())])
ax[1].set_ylabel('-ve slope 2')
ax[2].bar(list(dict_joint.keys()),[abs(v) for v in list(dict_joint.values())])
ax[2].set_ylabel('joint')
fig.suptitle('full FPT')
# Out:
# Text(0.5, 0.98, 'full FPT')

# %% [markdown]
# Plot full sync time

# %%
# Define grid size
nrows, ncols = 4, 4
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))
dict_exp1={}
dict_exp2={}
dict_slp1_vals={}
dict_joint={}
# using slope 2 values for ST as the fit is better
dict_slp2_vals={}
# Flatten axes for easy iteration
axes = axes.flatten()

for ax, file in zip(axes, files):
    print(f'Processing file: {file}')
   
    with open(file, "rb") as f:
        params = pickle.load(f)

    full_st = [x for x in params[2]["s_t"] if 25 < x < 800]

    

    nw = file.split('_')[-1].split('.')[-2]

    p=fit_piecewiseLinear(full_st, ax, f'full_st_{nw}')

    

    # directly assign into dicts
    dict_exp1[nw] = p['exp'][0]
    dict_exp2[nw] = p['exp'][1]
    dict_joint[nw] = p['joint']
    dict_slp1_vals[nw]=p['slope_1_entries']
    dict_slp2_vals[nw]=p['s2']
    

plt.tight_layout()
# plt.savefig('../../data/results/Part_FPT_fit.png', format='png')
plt.show()
# Out:
# Processing file: ..\..\data\results\calculate_final_params\final_bla.pkl
# Slopes of fitted lines: [-0.0124698  -0.02542487]
# Processing file: ..\..\data\results\calculate_final_params\final_enti.pkl
# Slopes of fitted lines: [-0.00354415 -0.00978775]
# Processing file: ..\..\data\results\calculate_final_params\final_fn.pkl
# Slopes of fitted lines: [-0.00012719 -0.00591824]
# Processing file: ..\..\data\results\calculate_final_params\final_lha.pkl
# Slopes of fitted lines: [-0.01870001 -0.00660206]
# Processing file: ..\..\data\results\calculate_final_params\final_lsc.pkl
# Slopes of fitted lines: [-0.00681626 -0.06934802]
# Processing file: ..\..\data\results\calculate_final_params\final_mob.pkl
# Slopes of fitted lines: [-0.00465633 -0.01070883]
# Processing file: ..\..\data\results\calculate_final_params\final_mop.pkl
# Slopes of fitted lines: [-0.00641735 -0.02599155]
# Processing file: ..\..\data\results\calculate_final_params\final_mos.pkl
# Slopes of fitted lines: [-0.00251584 -0.0203374 ]
# Processing file: ..\..\data\results\calculate_final_params\final_mrn.pkl
# Slopes of fitted lines: [-0.00516691 -0.0198052 ]
# Processing file: ..\..\data\results\calculate_final_params\final_orb.pkl
# Slopes of fitted lines: [-0.00474146 -0.02311494]
# Processing file: ..\..\data\results\calculate_final_params\final_peri.pkl
# Slopes of fitted lines: [-0.00743051 -0.01107752]
# Processing file: ..\..\data\results\calculate_final_params\final_pir.pkl
# Slopes of fitted lines: [-0.00421232 -0.00662441]
# Processing file: ..\..\data\results\calculate_final_params\final_re.pkl
# Slopes of fitted lines: [-0.004665   -0.10987356]

# %%
np.mean(dict_slp2_vals['fn'])
# Out:
# 299.8484848484849

# %% [markdown]
# Store ST values corresponding to slope 1

# %%
reader.data_dump_pkl('results/st_slop1_val_full.pkl',dict_slp1_vals)

# %% [markdown]
# Store ST values corresponding to slope 1

# %%
dict_slp1_vals
# Out:
# {'bla': [160.0, 160.0, 170.0, 185.0, 220.0, 250.0],
#  'enti': [120.0,
#   130.0,
#   150.0,
#   160.0,
#   170.0,
#   240.0,
#   260.0,
#   285.0,
#   350.0,
#   360.0,
#   360.0],
#  'fn': [125.0, 125.0],
#  'lha': [125.0,
#   135.0,
#   140.0,
#   145.0,
#   155.0,
#   160.0,
#   160.0,
#   175.0,
#   180.0,
#   180.0,
#   185.0,
#   195.0,
#   205.0,
#   215.0],
#  'lsc': [140.0, 145.0, 155.0, 165.0, 200.0, 205.0, 210.0, 290.0, 295.0, 310.0],
#  'mob': [110.0,
#   170.0,
#   175.0,
#   175.0,
#   175.0,
#   195.0,
#   215.0,
#   215.0,
#   225.0,
#   225.0,
#   230.0,
#   235.0,
#   265.0],
#  'mop': [125.0,
#   150.0,
#   150.0,
#   155.0,
#   170.0,
#   170.0,
#   175.0,
#   180.0,
#   200.0,
#   230.0,
#   230.0,
#   235.0,
#   235.0,
#   265.0,
#   270.0],
#  'mos': [115.0, 210.0, 230.0],
#  'mrn': [125.0,
#   175.0,
#   180.0,
#   180.0,
#   180.0,
#   195.0,
#   220.0,
#   260.0,
#   265.0,
#   265.0,
#   275.0,
#   275.0,
#   280.0,
#   285.0,
#   295.0,
#   320.0,
#   445.0,
#   455.0,
#   540.0],
#  'orb': [135.0,
#   135.0,
#   170.0,
#   170.0,
#   175.0,
#   180.0,
#   185.0,
#   205.0,
#   205.0,
#   210.0,
#   245.0,
#   260.0,
#   275.0,
#   315.0,
#   315.0,
#   340.0,
#   355.0,
#   365.0,
#   370.0,
#   370.0,
#   420.0,
#   475.0,
#   475.0,
#   495.0,
#   505.0,
#   590.0],
#  'peri': [160.0, 165.0, 175.0, 190.0],
#  'pir': [125.0, 130.0, 135.0, 140.0, 145.0, 150.0, 175.0, 175.0, 195.0, 275.0],
#  're': [165.0,
#   170.0,
#   185.0,
#   185.0,
#   195.0,
#   245.0,
#   270.0,
#   270.0,
#   275.0,
#   330.0,
#   335.0,
#   355.0,
#   380.0,
#   405.0,
#   425.0,
#   455.0,
#   465.0]}

# %%
reader.data_dump_pkl('results/st_slop1_val_full.pkl',dict_slp1_vals)

# %% [markdown]
# Store ST values corresponding to slope 2

# %%
reader.data_dump_pkl('results/st_slop2_val_full.pkl',dict_slp2_vals)

# %% [markdown]
# Plot bar charts for fulll st

# %%
fig,ax = plt.subplots(1,3,figsize=(15,3))
# networks=list(dict_exp1.keys())
ax[0].bar(list(dict_exp1.keys()),[abs(v) for v in list(dict_exp1.values())])
ax[0].set_ylabel('-ve slope 1')
ax[1].bar(list(dict_exp2.keys()),[abs(v) for v in list(dict_exp2.values())])
ax[1].set_ylabel('-ve slope 2')
ax[2].bar(list(dict_joint.keys()),[abs(v) for v in list(dict_joint.values())])
ax[2].set_ylabel('joint')
fig.suptitle('full ST')
# Out:
# Text(0.5, 0.98, 'full ST')

# %% [markdown]
# Plot part sync time

# %%
# Define grid size
nrows, ncols = 4, 4
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))

# Flatten axes for easy iteration
axes = axes.flatten()

for ax, file in zip(axes, files):
    print(f'Processing file: {file}')
   
    with open(file, "rb") as f:
        params = pickle.load(f)

    part_st = [x for x in params[1]["s_t"] if 25 < x < 800]

    

    nw = file.split('_')[-1].split('.')[-2]

    p=fit_piecewiseLinear(part_st, ax, f'part_st_{nw}')

    

    # directly assign into dicts
    dict_exp1[nw] = p['exp'][0]
    dict_exp2[nw] = p['exp'][1]
    dict_joint[nw] = p['joint']
    

plt.tight_layout()
# plt.savefig('../../data/results/Part_FPT_fit.png', format='png')
plt.show()
# Out:
# Processing file: ..\..\data\results\calculate_final_params\final_bla.pkl
# Slopes of fitted lines: [-0.01861519 -0.00376405]
# Processing file: ..\..\data\results\calculate_final_params\final_enti.pkl
# Slopes of fitted lines: [-0.02865887 -0.00808058]
# Processing file: ..\..\data\results\calculate_final_params\final_fn.pkl
# Slopes of fitted lines: [-0.02424203 -0.0137362 ]
# Processing file: ..\..\data\results\calculate_final_params\final_lha.pkl
# Slopes of fitted lines: [-0.03244779 -0.0079358 ]
# Processing file: ..\..\data\results\calculate_final_params\final_lsc.pkl
# Slopes of fitted lines: [-0.02284229 -0.00791417]
# Processing file: ..\..\data\results\calculate_final_params\final_mob.pkl
# Slopes of fitted lines: [-0.02858035 -0.00603358]
# Processing file: ..\..\data\results\calculate_final_params\final_mop.pkl
# Slopes of fitted lines: [-0.0217308  -0.00858774]
# Processing file: ..\..\data\results\calculate_final_params\final_mos.pkl
# Slopes of fitted lines: [-0.02067462 -0.0068956 ]
# Processing file: ..\..\data\results\calculate_final_params\final_mrn.pkl
# Slopes of fitted lines: [-0.02625952 -0.00944355]
# Processing file: ..\..\data\results\calculate_final_params\final_orb.pkl
# Slopes of fitted lines: [-0.02082342 -0.01101644]
# Processing file: ..\..\data\results\calculate_final_params\final_peri.pkl
# Slopes of fitted lines: [-0.03706712 -0.02383173]
# Processing file: ..\..\data\results\calculate_final_params\final_pir.pkl
# Slopes of fitted lines: [-0.03477017 -0.01222297]
# Processing file: ..\..\data\results\calculate_final_params\final_re.pkl
# Slopes of fitted lines: [-0.02558904 -0.00797233]

# %% [markdown]
# Plot bar charts

# %%
fig,ax = plt.subplots(1,3,figsize=(15,3))
# networks=list(dict_exp1.keys())
ax[0].bar(list(dict_exp1.keys()),[abs(v) for v in list(dict_exp1.values())])
ax[0].set_ylabel('-ve slope 1')
ax[1].bar(list(dict_exp2.keys()),[abs(v) for v in list(dict_exp2.values())])
ax[1].set_ylabel('-ve slope 2')
ax[2].bar(list(dict_joint.keys()),[abs(v) for v in list(dict_joint.values())])
ax[2].set_ylabel('joint')
fig.suptitle('part ST')
# Out:
# Text(0.5, 0.98, 'part ST')

# %% [markdown]
# ### Compute clusterwise params

# %% [markdown]
# Compute data..
# - Already stored in ../../data/results/comm_umap_results

# %%
folder_path=Path('../../data/raw/workstation/')
files_go=glob.glob(str(folder_path/'tes_*_go.bz2'))
files_nc=glob.glob(str(folder_path/'tes_*_nc.bz2'))
# avg_data=comm_partcptn.compute_community_participation()
# reader.data_dump_pkl(f'raw/workstation/pca_results/pca_avg_mos', avg_data)

# %%
# uncomment below to use this
data_folder=Path('../../data/results/comm_umap_results')

store_nw=[]
nw_name=[]
for f_go, f_nc in zip(files_go, files_nc):
    print(f'Processing files: {f_go} and {f_nc}')
    df_go=pd.read_pickle(f_go, compression="bz2")
    df_nc=pd.read_pickle(f_nc, compression="bz2")
    comm_ops.reset()
    l=comm_ops.get_avg_comm_particptn(df_go,df_nc)

    store_nw.append(l)
    nw_name.append(f_go.split('_')[-2])

    pca_full=pd.DataFrame({
    'mo':comm_ops.full_mo_per,
    'vis':comm_ops.full_vis_per,
    'orb':comm_ops.full_orb_per,
    'hth':comm_ops.full_hth_per,
    'olf':comm_ops.full_olf_per,
    'hipp':comm_ops.full_hipp_per,
    'mid':comm_ops.full_mid_per,
    'hind':comm_ops.full_hind_per
    })
    
    pca_full.to_pickle(data_folder/f'pca_full_df_{f_go.split("_")[-2]}', compression="bz2")
    
    

    pca_part=pd.DataFrame({
    'mo':comm_ops.part_mo_per,
    'vis':comm_ops.part_vis_per,
    'orb':comm_ops.part_orb_per,
    'hth':comm_ops.part_hth_per,
    'olf':comm_ops.part_olf_per,
    'hipp':comm_ops.part_hipp_per,
    'mid':comm_ops.part_mid_per,
    'hind':comm_ops.part_hind_per
    })
    
    pca_part.to_pickle(data_folder/f'pca_part_df_{f_go.split("_")[-2]}', compression="bz2")

    avg_data=comm_ops.compute_community_participation()
    reader.data_dump_pkl(f'results/comm_umap_results/pca_avg_{f_go.split("_")[-2]}', avg_data)

# %% [markdown]
# Store corresponding iteration number and index of transition in that iteration separately for partial and full
# - results/comm_umap_results/part_full_comm_ind.pkl

# %%
keys = nw_name
vals= store_nw
partial_full_dict = dict(zip(keys,vals))
reader.data_dump_pkl('results/comm_umap_results/part_full_comm_ind.pkl',partial_full_dict)

# %% [markdown]
# Plot scatter plot avg community participation for partial and full transitions in a network

# %%
data_folder=Path('../../data/results/comm_umap_results')
avg_files = glob.glob(str(data_folder/'pca_avg_*'))

# %%
def scatter_plot_btwn_part_full(avg_comm_per, network, ax=None): 
    # Sort 'Full Transitions' by value
    full_sorted = dict(sorted(avg_comm_per['avg_full'].items(), key=lambda x: x[1]))

    # Reorder 'Partial Transitions' to match the order of 'Full Transitions' keys
    part_sorted = {k: avg_comm_per['avg_part'].get(k, 0) for k in full_sorted.keys()}
    print(full_sorted)
    print(part_sorted)

    # Use provided axis or fallback to current axis
    if ax is None:
        ax = plt.gca()

    # Create scatter plot on the given axis
    ax.scatter(full_sorted.values(), part_sorted.values(), color='orange')

    # Add labels for each point
    for k, x, y in zip(full_sorted.keys(), full_sorted.values(), part_sorted.values()):
        ax.text(x, y, k, fontsize=9)

    ax.set_xlabel('Full Transitions (%)')
    ax.set_ylabel('Partial Transitions (%)')
    ax.set_title(f'Scatter Plot: Full vs Partial Transitions {network}')
    ax.grid(True)

# %%
# Define grid size
nrows, ncols = 4, 4
fig, axes = plt.subplots(nrows, ncols, figsize=(16, 16))

# Flatten axes for easy iteration
axes = axes.flatten()

for ax, file in zip(axes, avg_files):
    print(f'Processing file: {file}')
    with open(file, "rb") as f:
        pkl = pickle.load(f)
    
    # Pass the axis to your plotting function
    scatter_plot_btwn_part_full(pkl, file.split('_')[-1], ax=ax)

# Hide unused subplots if fewer than 16 files
for ax in axes[len(avg_files):]:
    ax.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_bla
# {'HIND': 4.812917103434537, 'MID': 60.23232131930888, 'MO': 68.45806867515515, 'HIPP': 69.38796655109117, 'HTh': 74.11714534700462, 'VIS': 78.38672241484805, 'ORB': 81.27146045038452, 'OLF': 86.03241779409431}
# {'HIND': 1.2815065668620271, 'MID': 15.615772370205471, 'MO': 28.40747422020931, 'HIPP': 21.4977132963162, 'HTh': 26.936994881648292, 'VIS': 25.264027703146457, 'ORB': 37.96504093308468, 'OLF': 53.82633125692413}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_enti
# {'HIND': 4.6944713559560745, 'MID': 57.82732087145741, 'HIPP': 62.12433474031933, 'HTh': 69.81351874405645, 'MO': 70.46728757570196, 'VIS': 74.92644521930629, 'ORB': 79.34256690380317, 'OLF': 79.36270161701434}
# {'HIND': 1.1890265740276484, 'MID': 13.462336406520205, 'HIPP': 13.842203280567295, 'HTh': 19.17879189430296, 'MO': 30.321776479376222, 'VIS': 19.3955662201848, 'ORB': 34.77681524583188, 'OLF': 44.15469880381062}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_fn
# {'HIND': 4.547796100384085, 'MID': 55.249919849911535, 'HIPP': 64.7129602693043, 'MO': 68.31634534892005, 'HTh': 72.54184974799949, 'VIS': 73.10662039730695, 'ORB': 79.30604822346194, 'OLF': 86.53162489956502}
# {'HIND': 0.782372454989318, 'MID': 11.561681583202386, 'HIPP': 17.83522455545411, 'MO': 26.37685525059987, 'HTh': 23.43015718684168, 'VIS': 20.26548121096184, 'ORB': 34.07895308899613, 'OLF': 50.681170061849166}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_lha
# {'HIND': 3.4260616163498585, 'MID': 49.08679574008989, 'HIPP': 55.301332905412856, 'HTh': 63.814977885203646, 'MO': 66.50075793503537, 'VIS': 69.44423159858385, 'ORB': 76.1398544795073, 'OLF': 85.32976621500998}
# {'HIND': 0.6373016648857097, 'MID': 9.517638857253294, 'HIPP': 13.622476687442624, 'HTh': 18.081847610764846, 'MO': 26.77299677662049, 'VIS': 18.10467217471131, 'ORB': 32.216746388365465, 'OLF': 54.420340038545575}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_lsc
# {'HIND': 4.5337037161905265, 'MID': 57.322235441197144, 'HIPP': 65.32825049470377, 'MO': 68.67611567224534, 'HTh': 73.61796796763093, 'VIS': 75.26622998698427, 'ORB': 80.76831742210011, 'OLF': 86.9596911966834}
# {'HIND': 1.0501749757721748, 'MID': 14.371380031878678, 'HIPP': 16.704571244908266, 'MO': 30.886615172263863, 'HTh': 24.05993382163087, 'VIS': 23.439538743088033, 'ORB': 38.228657549617026, 'OLF': 57.43513301367197}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_mob
# {'HIND': 4.455566310241461, 'MID': 54.043485542933155, 'HIPP': 64.522343471693, 'MO': 68.1517053927742, 'VIS': 69.84479065677631, 'HTh': 73.01139566248466, 'ORB': 79.22849240252997, 'OLF': 82.23068964394241}
# {'HIND': 0.6528899291504637, 'MID': 10.052352379874174, 'HIPP': 18.773712215555303, 'MO': 23.64497582119002, 'VIS': 17.60932865391147, 'HTh': 26.59044595164826, 'ORB': 32.46522066315488, 'OLF': 49.45252651043435}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_mop
# {'HIND': 2.846916537061027, 'MID': 50.81378717780642, 'MO': 58.48031873401501, 'HIPP': 63.214269353253684, 'VIS': 72.27889965198501, 'HTh': 73.85444227928656, 'ORB': 80.00704548882263, 'OLF': 88.43355081191181}
# {'HIND': 0.44396458230579744, 'MID': 7.716305556262784, 'MO': 18.46720242187055, 'HIPP': 12.957846407142434, 'VIS': 14.728484015242168, 'HTh': 19.448501359034243, 'ORB': 27.21217875851107, 'OLF': 50.89572730813151}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_mos
# {'HIND': 4.2219538712630955, 'MID': 54.445869047474076, 'MO': 64.65246016572173, 'HIPP': 66.78441735572414, 'VIS': 73.93012409123567, 'HTh': 73.98185737202019, 'ORB': 79.02476308910744, 'OLF': 87.2109645722296}
# {'HIND': 0.446552824207348, 'MID': 8.110432161631124, 'MO': 16.412330648396754, 'HIPP': 17.160178584287465, 'VIS': 14.374926189961835, 'HTh': 23.75169386672951, 'ORB': 24.928710304601427, 'OLF': 49.498751830248914}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_mrn
# {'HIND': 2.746627930415684, 'MID': 46.12796939777413, 'HIPP': 59.058021054821864, 'MO': 61.258143114452736, 'VIS': 67.32153795134893, 'HTh': 72.67173618635687, 'ORB': 77.39655134823764, 'OLF': 86.64891507194923}
# {'HIND': 0.5019136824874086, 'MID': 9.365523367445912, 'HIPP': 16.399577386725785, 'MO': 23.499883707120095, 'VIS': 18.753637245392824, 'HTh': 24.47118230944613, 'ORB': 32.20024309432794, 'OLF': 54.099743275907194}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_orb
# {'HIND': 4.183963758772883, 'MID': 50.9095601503974, 'HIPP': 60.32244438990142, 'MO': 66.82424118380463, 'HTh': 68.25005461509203, 'VIS': 69.18710222440394, 'ORB': 72.39672817977888, 'OLF': 86.26365716032541}
# {'HIND': 0.5292460805915361, 'MID': 8.910233296558404, 'HIPP': 14.686136748916933, 'MO': 21.506437854855637, 'HTh': 18.693898868131303, 'VIS': 16.28127707666227, 'ORB': 26.646898164049947, 'OLF': 47.66630564450305}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_peri
# {'HIND': 5.015017193374532, 'MID': 58.5021079044838, 'MO': 64.74901083342814, 'HIPP': 68.06249446951597, 'VIS': 72.89177948854083, 'HTh': 76.99069772586496, 'ORB': 79.93254110776246, 'OLF': 86.38582254274449}
# {'HIND': 0.7560268775508641, 'MID': 10.437399134668885, 'MO': 18.43496452585336, 'HIPP': 20.698703664231598, 'VIS': 15.516615962950763, 'HTh': 27.359352237275775, 'ORB': 27.89920200064059, 'OLF': 50.145544424421324}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_pir
# {'HIND': 4.467937962146657, 'MID': 53.86137376743067, 'HIPP': 62.93070076693203, 'MO': 68.86094280924576, 'VIS': 69.33998493670988, 'HTh': 69.9623564993385, 'ORB': 79.30450664866567, 'OLF': 79.3168384007717}
# {'HIND': 0.7517579794348856, 'MID': 10.97175399535263, 'HIPP': 16.18133024228603, 'MO': 26.37684198400599, 'VIS': 18.52521765424788, 'HTh': 20.324285071226573, 'ORB': 32.85458168954689, 'OLF': 39.43909670862259}
# Processing file: ..\..\data\results\comm_umap_results\pca_avg_re
# {'HIND': 4.700537385707501, 'MID': 50.798950229184946, 'HIPP': 61.53974000236464, 'MO': 69.63264254788996, 'HTh': 70.10389310605507, 'VIS': 71.80901602887111, 'ORB': 78.72492663493723, 'OLF': 86.88334074628743}
# {'HIND': 0.9968992248062015, 'MID': 12.122365154592643, 'HIPP': 18.279519747235387, 'MO': 30.33893026404875, 'HTh': 25.220594571305472, 'VIS': 20.29148815165877, 'ORB': 37.76360932998792, 'OLF': 59.43263120940846}

# %%
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# from sklearn.metrics import pairwise_distances_argmin

# %% [markdown]
# Define a consistent colormap for 5 clusters

# %% [markdown]
# Assign cluster labels to embeddings
# Group the iterations using cluster label
# Trace back that iteration and transition using results/comm_umap_results/part_full_comm_ind.pkl

# %%
df_par= reader.data_read_bz2('results/comm_umap_results/pca_part_df_fn')

# %%
df_par.head()
# Out:
#           mo        vis        orb        hth        olf       hipp  \
# 0  33.993310  31.456193  47.334281  42.100385  63.183954  29.326284
# 1  26.437359  19.820738  37.785589  31.458699  52.089436  11.374341
# 2  33.040329   7.310078  46.006232  14.617101  86.032156  33.537468
# 3  16.945289  24.801418  19.138506   7.390393  16.893223   3.304965
# 4   0.112309   0.025157   0.049328   0.014294   0.209644   0.029350
#
#          mid      hind
# 0  26.689685  0.384669
# 1  17.878484  0.633506
# 2   5.210410  0.145724
# 3   7.512665  0.494805
# 4   0.029949  0.068256

# %%
df_par.shape
# Out:
# (187, 8)

# %% [markdown]
# - To use this file

# %%
nw_itr= reader.data_read_pkl('results/comm_umap_results/part_full_comm_ind.pkl')

# %%
# find NaN rows index of entries x 8 vector space
nan_indices = df_par.index[df_par.isnull().any(axis=1)].tolist()

# removing the NaN row
if not nan_indices:
    pass
else:
    # dropping NaN value
    df_par.dropna(inplace = True)

# removing nan entries from nw_itr of given network
i_part=nw_itr['fn']['part_ind'].copy()
for i in nan_indices:
    new_part_ind = [val for i, val in enumerate(i_part) if i not in nan_indices]

embedding_part = _reducer.transform(df_par.values)
part_network_labels = assign_clusters(embedding_part,ref_centroids)
print(len(part_network_labels))
# Out:
# 186
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
# assigning cluster labels to our 186 x2 vector space  
df_embed = pd.DataFrame(embedding_part)
df_embed['cluster'] = part_network_labels
df_embed.head()
# Out:
#           0         1  cluster
# 0  6.603561  2.301683        2
# 1  8.332043  7.593044        4
# 2  8.411141  1.513047        1
# 3  6.133539  8.949895        0
# 4 -1.848074  9.405300        3

# %%
# Group indices cluster-wise
cluster_indices = {c: df_embed.index[df_embed['cluster'] == c].tolist() for c in df_embed['cluster'].unique()}

print(cluster_indices)
# Out:
# {2: [0, 9, 11, 12, 13, 17, 20, 37, 45, 63, 71, 78, 83, 91, 96, 125, 131, 148, 151, 152, 153, 154, 155, 181], 4: [1, 6, 8, 21, 28, 29, 35, 38, 39, 40, 44, 49, 50, 51, 52, 55, 62, 64, 69, 73, 74, 75, 77, 93, 97, 99, 100, 101, 104, 106, 113, 115, 118, 123, 127, 128, 137, 139, 140, 143, 144, 145, 146, 157, 159, 167, 168, 171, 173, 177], 1: [2, 10, 15, 30, 32, 47, 57, 58, 59, 60, 85, 110, 129, 142, 147, 156, 158, 161, 162, 169, 183], 0: [3, 5, 16, 18, 19, 22, 23, 24, 27, 31, 34, 36, 46, 48, 54, 56, 61, 66, 67, 80, 81, 84, 88, 89, 94, 102, 105, 107, 108, 109, 111, 112, 116, 117, 120, 130, 133, 134, 135, 136, 138, 141, 149, 164, 165, 166, 170, 172, 178, 179, 180, 184, 185], 3: [4, 7, 14, 25, 26, 33, 41, 42, 43, 53, 65, 68, 70, 72, 76, 79, 82, 86, 87, 90, 92, 95, 98, 103, 114, 119, 121, 122, 124, 126, 132, 150, 160, 163, 174, 175, 176, 182]}

# %%
len(cluster_indices[0])
# Out:
# 53

# %%
cluster_indices.keys()
# Out:
# dict_keys([2, 4, 1, 0, 3])

# %% [markdown]
# - Take 1 cluster at a time
# - Take the indices
# - Map those indices to new_part_indices so that we get iteration number

# %%
# Out:
# (0, 0)

# %%
clus_params={}
for i in range(0,5):

    # saving clusterwise params data
    fpt=[]
    st=[]
    cov=[]
    tt=[]
    for ind in cluster_indices[i]:
        

        # getting actual iteration number
        itrn = new_part_ind[ind]
        
        # compute params
        pts=algo_umap.compute_parameters(df_go[itrn[0]])
        fpt_list=algo.compute_fpt(pts['start_points'].copy(),pts['stop_points'].copy())[itrn[1]]
        fpt.append(fpt_list)
        st_list = algo.compute_sync(pts['start_points'].copy(),pts['stop_points'].copy())
        if itrn[1]  < len(st_list):
            # consider case when transition doesn't falls back
            st.append(st_list[itrn[1]])
        
        cov_list = comm_ops.compute_individual_coverage_nc(df_nc.loc[itrn[0]], df_go[itrn[0]])[itrn[1]]
        cov.append(cov_list)
        tt_list = algo_umap.compute_transition_time(df_go[itrn[0]],pts['start_points'].copy())[itrn[1]]
        tt.append(tt_list)

    clus_params[i]={'fpt':fpt,'st':st, 'cov':cov, 'tt':tt}
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:190: RuntimeWarning: invalid value encountered in scalar divide
#   percentage=(count_true/tot)*100
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:509: RuntimeWarning: invalid value encountered in scalar divide
#   coverage = node_mc / total_nodes
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:190: RuntimeWarning: invalid value encountered in scalar divide
#   percentage=(count_true/tot)*100
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:509: RuntimeWarning: invalid value encountered in scalar divide
#   coverage = node_mc / total_nodes
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:190: RuntimeWarning: invalid value encountered in scalar divide
#   percentage=(count_true/tot)*100
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:509: RuntimeWarning: invalid value encountered in scalar divide
#   coverage = node_mc / total_nodes
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# ...
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:190: RuntimeWarning: invalid value encountered in scalar divide
#   percentage=(count_true/tot)*100
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:509: RuntimeWarning: invalid value encountered in scalar divide
#   coverage = node_mc / total_nodes
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:190: RuntimeWarning: invalid value encountered in scalar divide
#   percentage=(count_true/tot)*100
# D:\srg-tes-epilepsy-models\analysis\tes\commAnalysis.py:509: RuntimeWarning: invalid value encountered in scalar divide
#   coverage = node_mc / total_nodes
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell
# this cell
# this cell
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# this cell

# %%
len(clus_params[0]['cov'])
# Out:
# 53

# %%
plt.violinplot(clus_params[2]['tt'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x24bd99d1b10>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x24bd99d0490>,
#  'cmins': <matplotlib.collections.LineCollection at 0x24bde06ed40>,
#  'cbars': <matplotlib.collections.LineCollection at 0x24bde06c9d0>}

# %%
plt.violinplot(clus_params[4]['tt'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x24bddfd1a80>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x24bddfd05b0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x24bddfd3910>,
#  'cbars': <matplotlib.collections.LineCollection at 0x24bddfd39d0>}

# %%
nw_itr['fn']['part_ind'][ind]
# Out:
# (85, 6)

# %%
new_part_ind[ind]
# Out:
# (89, 0)

# %%
pts
# Out:
# {'start_points': [5000], 'stop_points': []}

# %%
itrn
# Out:
# (137, 1)

# %%
st_list
# Out:
# 75.0

# %%
# for the above index in new_part_ind
# for cluster 2
itrn=new_part_ind[cluster_indices[2][17]]
itrn
# Out:
# (129, 1)

# %%
itrn[0]
# Out:
# 129

# %%
# here 129 is iteration number
# 1 is transition number in that iteration

# since this is of FN
df_go = reader.data_read_bz2('raw/workstation/tes_fn_go.bz2')
df_nc = reader.data_read_bz2('raw/workstation/tes_fn_nc.bz2')

# %%
itr = itrn[0]
pts=algo_umap.compute_parameters(df_go[itrn[0]])
fpt_list=algo.compute_fpt(pts['start_points'].copy(),pts['stop_points'].copy())

st_list = algo.compute_sync(pts['start_points'].copy(),pts['stop_points'].copy())

cov_list = comm_ops.compute_individual_coverage_nc(df_nc.loc[itrn[0]], df_go[itrn[0]])

tt_list = algo_umap.compute_transition_time(df_go[itrn[0]],pts['start_points'].copy())
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
algo_umap.plot_transition(df_go[itrn[0]],pts['start_points'],pts['stop_points'])
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
fpt_list
# Out:
# [520.0, 345.0]

# %%
st_list
# Out:
# [1120.0]

# %%
cov_list
# Out:
# [0.3849636150234742, 0.26966118796854543]

# %%
tt_list
# Out:
# [44.150000000000006, 29.900000000000002, 36.85, 40.45]

# %%
pts
# Out:
# {'start_points': [9100, 20500, 24500, 34800],
#  'stop_points': [9900, 21400, 25100, 35500]}

# %%
# take each cluster
for clus in cluster_indices.keys():
    print(clus)
    for itr in cluster_indices[clus]:
# Out:
# 2
# 4
# 1
# 0
# 3

# %%
i_part[108]
# Out:
# (85, 6)

# %%
df_go=reader.data_read_bz2('raw/workstation/tes_fn_go.bz2')
df_nc=reader.data_read_bz2('raw/workstation/tes_fn_nc.bz2')

# %%
itr=85
pts=algo_umap.compute_parameters(df_go[itr])
algo_umap.plot_transition(df_go[itr],pts['start_points'],pts['stop_points'])
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
pts
# Out:
# {'start_points': [10900, 15600, 16900, 18900, 22800, 28000, 32700],
#  'stop_points': [12900, 16400, 17900, 19500, 24100, 28700, 33100]}

# %%
len(nw_itr['fn']['part_ind'])
# Out:
# 187

# %%
nw_itr['fn']['part_ind'][108]
# Out:
# (85, 6)

# %%
print(df_par.shape)
# Out:
# (187, 8)

# %%
df = df_par.copy()
nan_indices = df.index[df.isnull().any(axis=1)].tolist()
print(nan_indices)
# Out:
# [108]

# %%
df.iloc[108:]
# Out:
#             mo        vis        orb        hth        olf       hipp  \
# 108        NaN        NaN        NaN        NaN        NaN        NaN
# 109  16.241964   9.092000  22.086765  12.045455  61.148611  12.577000
# 110  19.875890  16.260997  36.963084  20.727806  64.393939  21.788856
# 111  27.769841   6.219259  45.664488  32.417508  63.115226  28.714074
# 112  19.822950  19.812500  35.473763  10.230501  61.734533  14.457386
# ..         ...        ...        ...        ...        ...        ...
# 182  30.638285  24.455017  52.114289  53.391397  86.072664  36.598616
# 183   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 184  22.682954  21.717791  30.250812  40.149191  56.970007  27.315951
# 185   7.896601   2.028329  16.380603  12.702807  53.753541   5.087819
# 186   4.839417  13.056511   9.228212   6.176011  43.297843  10.447174
#
#            mid      hind
# 108        NaN       NaN
# 109   3.890714  0.132558
# 110   7.635107  0.985474
# 111   7.716402  0.141258
# 112   7.242289  0.056158
# ..         ...       ...
# 182  15.633959  0.276615
# 183   0.000000  0.000000
# 184   8.126643  0.526109
# 185   0.384460  0.191053
# 186   0.793261  0.251414
#
# [79 rows x 8 columns]

# %%
# remove NAN values
df_par.dropna(inplace = True)

# %%
df_par.shape
# Out:
# (186, 8)

# %% [markdown]
# #### Reading coverage_nc data

# %%
fn_cov=reader.data_read_pkl('raw/workstation/coverage_nc/coverage_nc_fn')
plt.violinplot(fn_cov,showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x258bf0be9e0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x258bf0bf280>,
#  'cmins': <matplotlib.collections.LineCollection at 0x258bf0bd600>,
#  'cbars': <matplotlib.collections.LineCollection at 0x258bf0bd1e0>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x258bf0bd360>}

# %%
thresh_info = reader.data_read_pkl('results/coverage_threshold.pkl')
thresh_info.keys()
# Out:
# dict_keys(['bla', 'enti', 'fn', 'lha', 'lsc', 'mob', 'mop', 'mos', 'mrn', 'orb', 'peri', 'pir', 're'])

# %% [markdown]
# Checking out compute_df function

# %%
partial_cov_data_fn = reader.data_read_pkl('results/calculate_final_params/final_fn.pkl')
p_cov=partial_cov_data_fn[1]['cov']
p_cov=[x for x in p_cov if x>0]
_, mw = mannwhitneyu(fn_data[1]["cov"], p_cov)
print(mw)
plt.hist(p_cov,bins=10)
# Out:
# nan
# (array([29.,  6., 13., 25., 28., 30., 20.,  8., 11., 10.]),
#  array([1.28625635e-05, 3.88208486e-02, 7.76288347e-02, 1.16436821e-01,
#         1.55244807e-01, 1.94052793e-01, 2.32860779e-01, 2.71668765e-01,
#         3.10476751e-01, 3.49284737e-01, 3.88092723e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(fn_data[1]["cov"],bins=10)
# Out:
# (array([35.,  6., 13., 25., 28., 30., 20.,  8., 11., 10.]),
#  array([0.        , 0.03880927, 0.07761854, 0.11642782, 0.15523709,
#         0.19404636, 0.23285563, 0.27166491, 0.31047418, 0.34928345,
#         0.38809272]),
#  <BarContainer object of 10 artists>)

# %%
df_go=reader.data_read_bz2('raw/workstation/tes_fn_go.bz2')
df_nc=reader.data_read_bz2('raw/workstation/tes_fn_nc.bz2')

# %%
comm_ops.get_avg_comm_particptn(df_go,df_nc)
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...
# 196 0
# full: [87.70277777777777, 85.27361111111111, 91.91805555555555, 79.82498394348106, 87.9888888888889, 63.47298534798534, 89.53472222222221, 87.48333333333333, 83.08162531463502, 89.13085559427023, 89.84258125934993, 94.29179566563467, 83.59444444444445, 86.40138888888889, 79.75138888888888, 87.49027777777778, 89.21805555555555, 82.5125, 87.41250000000001, 85.41250000000001, 83.06666666666666, 93.90833333333333, 84.13055555555556, 64.62350780532599, 83.26938817270309, 96.6361111111111, 87.08026550647033, 84.66505758807588, 90.82916666666667, 74.91201608848668, 88.7875, 87.7625, 92.9888888888889, 92.61666666666667, 86.15972222222223, 89.96111111111111, 69.35114503816794, 85.17464833254307, 87.35833333333333, 87.6888888888889, 86.41250000000001, 88.06666666666668, 85.86388888888888, 85.9875, 87.58749999999999, 88.81666666666666, 83.13888888888889, 82.54027777777779, 88.84583333333333, 86.60833333333333, 87.9486111111111, 85.8236111111111, 85.35555555555555, 90.54861111111111, 88.53055555555555, 91.76388888888889, 86.59027777777779, 82.70833333333333, 77.2486111111111, 86.50277777777777, 78.68792087542089, 88.38055555555555, 91.19444444444444, 80.43055555555556, 87.6861111111111, 79.29690027826311, 91.25833333333333, 85.0625, 86.94027777777778, 87.2125, 90.18055555555556, 85.6763888888889, 93.05416666666667, 90.17916666666666, 85.8625, 90.75277777777778, 91.08333333333334, 88.84166666666667, 90.42777777777778, 86.02361111111111, 87.6111111111111, 84.64780144896349, 88.68333333333334, 87.95972222222223, 90.89305555555556, 58.00744878957169, 86.72638888888888, 91.99305555555556, 89.08472222222223, 86.47083333333333, 86.63888888888889, 88.3138888888889, 85.08888888888889, 88.2125, 80.55138888888888, 82.82916666666667, 75.6338899196042, 67.57083333333334, 88.21388888888889, 86.67083333333333, 85.30416666666667, 88.2375]
# 196 1
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# full: [87.70277777777777, 85.27361111111111, 91.91805555555555, 79.82498394348106, 87.9888888888889, 63.47298534798534, 89.53472222222221, 87.48333333333333, 83.08162531463502, 89.13085559427023, 89.84258125934993, 94.29179566563467, 83.59444444444445, 86.40138888888889, 79.75138888888888, 87.49027777777778, 89.21805555555555, 82.5125, 87.41250000000001, 85.41250000000001, 83.06666666666666, 93.90833333333333, 84.13055555555556, 64.62350780532599, 83.26938817270309, 96.6361111111111, 87.08026550647033, 84.66505758807588, 90.82916666666667, 74.91201608848668, 88.7875, 87.7625, 92.9888888888889, 92.61666666666667, 86.15972222222223, 89.96111111111111, 69.35114503816794, 85.17464833254307, 87.35833333333333, 87.6888888888889, 86.41250000000001, 88.06666666666668, 85.86388888888888, 85.9875, 87.58749999999999, 88.81666666666666, 83.13888888888889, 82.54027777777779, 88.84583333333333, 86.60833333333333, 87.9486111111111, 85.8236111111111, 85.35555555555555, 90.54861111111111, 88.53055555555555, 91.76388888888889, 86.59027777777779, 82.70833333333333, 77.2486111111111, 86.50277777777777, 78.68792087542089, 88.38055555555555, 91.19444444444444, 80.43055555555556, 87.6861111111111, 79.29690027826311, 91.25833333333333, 85.0625, 86.94027777777778, 87.2125, 90.18055555555556, 85.6763888888889, 93.05416666666667, 90.17916666666666, 85.8625, 90.75277777777778, 91.08333333333334, 88.84166666666667, 90.42777777777778, 86.02361111111111, 87.6111111111111, 84.64780144896349, 88.68333333333334, 87.95972222222223, 90.89305555555556, 58.00744878957169, 86.72638888888888, 91.99305555555556, 89.08472222222223, 86.47083333333333, 86.63888888888889, 88.3138888888889, 85.08888888888889, 88.2125, 80.55138888888888, 82.82916666666667, 75.6338899196042, 67.57083333333334, 88.21388888888889, 86.67083333333333, 85.30416666666667, 88.2375, 91.65833333333333]
# 197 0
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# part: [63.18395434709634, 52.08943565709823, 86.03215618719494, 16.893223010244288, 0.20964360587002098, 47.29157541246897, 61.73391410667889, 0.4340277777777778, 61.35302605890841, 67.47916666666667, 61.90679170218812, 59.89527866524672, 80.93932748538012, 78.2516339869281, 0.050948077263866735, 80.18413149992098, 27.18855218855219, 82.55078772802653, 52.97692806986487, 73.81796690307328, 92.28059581320451, 59.988713318284425, 20.211315610088615, 31.822019587977035, 35.375816993464056, 0.11212384259259259, 16.051779935275082, 57.12752525252526, 44.27332877024869, 37.863888888888894, 84.30416666666667, 47.173489278752434, 88.67257244883945, 7.173202614379084, 42.00056834327934, 39.215430163706024, 64.68585577220675, 62.20062819002749, 37.29231568016615, 61.82506242197253, 50.02962962962963, 3.8527397260273974, 0.05957700327673518, 12.35632183908046, 67.7353195164076, 93.84861111111111, 59.67941400304414, 60.077186963979415, 55.9640522875817, 59.75772097976571, 62.765293383270915, 31.45145145145145, 42.27059591642925, 0.15432098765432098, 20.17241379310345, 65.95354523227384, 60.513361462728554, 80.29041530379621, 67.08410636982065, 69.81800766283524, 61.883629191321496, 43.94603934077618, 53.355028668836205, 83.52728468113084, 52.354151537158074, 0.04452664748595698, 53.31588132635253, 43.711419753086425, 13.896122685185187, 46.25925925925926, 0.4547251878212732, 65.66738816738817, 0.14158576051779936, 40.264367816091955, 53.327228327228326, 56.2086983248809, 0.0, 46.45224171539961, 83.17095080154782, 0.0, 70.29671717171718, 57.078598484848484, 0.0, 59.41673770957658, 28.51246746129607, 60.12731481481482, 0.0, 0.2074074074074074, 33.901591121807726, 32.07276570048309, 0.45622545622545624, 75.62965178096756, 0.624048706240487, 48.4763507197607, 27.674897119341562, 0.0, 74.85616684645811, 53.73015873015873, 0.0, 62.52947244326555, 57.27815916603102, 51.08515057113188, 60.190990363404154, 0.0, 53.944719018854116, 50.85419149781486, 52.87698412698413, 53.377896613190735, nan, 61.14861111111111, 64.39393939393939, 63.11522633744856, 61.73453282828283, 34.957206174537674, 69.10310734463276, 6.890459363957597, 64.4743689825657, 31.32669983416252, 22.421875, 43.144350623240854, 0.0, 48.67450437989857, 1.6288951841359773, 0.007271669575334497, 76.77916666666667, 1.2411347517730498, 63.56944444444444, 11.195286195286196, 50.07086167800453, 49.51388888888889, 82.24702380952381, 46.19444444444444, 78.78066378066379, 11.050394656952033, 39.75342053826492, 33.78060263653484, 55.0414722654225, 44.414014953921054, 53.889573070607554, 18.78066378066378, 57.51934588991093, 58.55003940110323, 41.43184421534937, 80.03414544112218, 49.33933933933934, 70.65789473684211, 64.26470588235294, 47.816248019914006, 77.22855935783693, 92.42165242165242, 31.153039832285117, 0.2997601918465228, 71.89166666666667, 89.13333333333333, 78.02222222222223, 86.01666666666667, 56.576869942766926, 63.17471590909091, 87.45138888888889, 86.67514843087362, 53.11179277436946, 0.0, 59.22648312028843, 63.36048730368413, 7.974910394265233, 40.63977541371158, 56.201344656758664, 29.62638888888889, 71.39305555555555, 62.22404172731684, 61.263179237631796, 42.675544794188866, 58.42145593869732, 39.04794364917064, 79.0416008425487, 0.05533421868083222, 0.13997760358342665, 0.0, 58.055957549445246, 35.154941373534335, 44.57724656927844, 51.67568961072442, 86.07266435986159, 0.0, 56.970006816632576]
# 199 0
# part: [63.18395434709634, 52.08943565709823, 86.03215618719494, 16.893223010244288, 0.20964360587002098, 47.29157541246897, 61.73391410667889, 0.4340277777777778, 61.35302605890841, 67.47916666666667, 61.90679170218812, 59.89527866524672, 80.93932748538012, 78.2516339869281, 0.050948077263866735, 80.18413149992098, 27.18855218855219, 82.55078772802653, 52.97692806986487, 73.81796690307328, 92.28059581320451, 59.988713318284425, 20.211315610088615, 31.822019587977035, 35.375816993464056, 0.11212384259259259, 16.051779935275082, 57.12752525252526, 44.27332877024869, 37.863888888888894, 84.30416666666667, 47.173489278752434, 88.67257244883945, 7.173202614379084, 42.00056834327934, 39.215430163706024, 64.68585577220675, 62.20062819002749, 37.29231568016615, 61.82506242197253, 50.02962962962963, 3.8527397260273974, 0.05957700327673518, 12.35632183908046, 67.7353195164076, 93.84861111111111, 59.67941400304414, 60.077186963979415, 55.9640522875817, 59.75772097976571, 62.765293383270915, 31.45145145145145, 42.27059591642925, 0.15432098765432098, 20.17241379310345, 65.95354523227384, 60.513361462728554, 80.29041530379621, 67.08410636982065, 69.81800766283524, 61.883629191321496, 43.94603934077618, 53.355028668836205, 83.52728468113084, 52.354151537158074, 0.04452664748595698, 53.31588132635253, 43.711419753086425, 13.896122685185187, 46.25925925925926, 0.4547251878212732, 65.66738816738817, 0.14158576051779936, 40.264367816091955, 53.327228327228326, 56.2086983248809, 0.0, 46.45224171539961, 83.17095080154782, 0.0, 70.29671717171718, 57.078598484848484, 0.0, 59.41673770957658, 28.51246746129607, 60.12731481481482, 0.0, 0.2074074074074074, 33.901591121807726, 32.07276570048309, 0.45622545622545624, 75.62965178096756, 0.624048706240487, 48.4763507197607, 27.674897119341562, 0.0, 74.85616684645811, 53.73015873015873, 0.0, 62.52947244326555, 57.27815916603102, 51.08515057113188, 60.190990363404154, 0.0, 53.944719018854116, 50.85419149781486, 52.87698412698413, 53.377896613190735, nan, 61.14861111111111, 64.39393939393939, 63.11522633744856, 61.73453282828283, 34.957206174537674, 69.10310734463276, 6.890459363957597, 64.4743689825657, 31.32669983416252, 22.421875, 43.144350623240854, 0.0, 48.67450437989857, 1.6288951841359773, 0.007271669575334497, 76.77916666666667, 1.2411347517730498, 63.56944444444444, 11.195286195286196, 50.07086167800453, 49.51388888888889, 82.24702380952381, 46.19444444444444, 78.78066378066379, 11.050394656952033, 39.75342053826492, 33.78060263653484, 55.0414722654225, 44.414014953921054, 53.889573070607554, 18.78066378066378, 57.51934588991093, 58.55003940110323, 41.43184421534937, 80.03414544112218, 49.33933933933934, 70.65789473684211, 64.26470588235294, 47.816248019914006, 77.22855935783693, 92.42165242165242, 31.153039832285117, 0.2997601918465228, 71.89166666666667, 89.13333333333333, 78.02222222222223, 86.01666666666667, 56.576869942766926, 63.17471590909091, 87.45138888888889, 86.67514843087362, 53.11179277436946, 0.0, 59.22648312028843, 63.36048730368413, 7.974910394265233, 40.63977541371158, 56.201344656758664, 29.62638888888889, 71.39305555555555, 62.22404172731684, 61.263179237631796, 42.675544794188866, 58.42145593869732, 39.04794364917064, 79.0416008425487, 0.05533421868083222, 0.13997760358342665, 0.0, 58.055957549445246, 35.154941373534335, 44.57724656927844, 51.67568961072442, 86.07266435986159, 0.0, 56.970006816632576, 53.75354107648725]
# 199 1
# part: [63.18395434709634, 52.08943565709823, 86.03215618719494, 16.893223010244288, 0.20964360587002098, 47.29157541246897, 61.73391410667889, 0.4340277777777778, 61.35302605890841, 67.47916666666667, 61.90679170218812, 59.89527866524672, 80.93932748538012, 78.2516339869281, 0.050948077263866735, 80.18413149992098, 27.18855218855219, 82.55078772802653, 52.97692806986487, 73.81796690307328, 92.28059581320451, 59.988713318284425, 20.211315610088615, 31.822019587977035, 35.375816993464056, 0.11212384259259259, 16.051779935275082, 57.12752525252526, 44.27332877024869, 37.863888888888894, 84.30416666666667, 47.173489278752434, 88.67257244883945, 7.173202614379084, 42.00056834327934, 39.215430163706024, 64.68585577220675, 62.20062819002749, 37.29231568016615, 61.82506242197253, 50.02962962962963, 3.8527397260273974, 0.05957700327673518, 12.35632183908046, 67.7353195164076, 93.84861111111111, 59.67941400304414, 60.077186963979415, 55.9640522875817, 59.75772097976571, 62.765293383270915, 31.45145145145145, 42.27059591642925, 0.15432098765432098, 20.17241379310345, 65.95354523227384, 60.513361462728554, 80.29041530379621, 67.08410636982065, 69.81800766283524, 61.883629191321496, 43.94603934077618, 53.355028668836205, 83.52728468113084, 52.354151537158074, 0.04452664748595698, 53.31588132635253, 43.711419753086425, 13.896122685185187, 46.25925925925926, 0.4547251878212732, 65.66738816738817, 0.14158576051779936, 40.264367816091955, 53.327228327228326, 56.2086983248809, 0.0, 46.45224171539961, 83.17095080154782, 0.0, 70.29671717171718, 57.078598484848484, 0.0, 59.41673770957658, 28.51246746129607, 60.12731481481482, 0.0, 0.2074074074074074, 33.901591121807726, 32.07276570048309, 0.45622545622545624, 75.62965178096756, 0.624048706240487, 48.4763507197607, 27.674897119341562, 0.0, 74.85616684645811, 53.73015873015873, 0.0, 62.52947244326555, 57.27815916603102, 51.08515057113188, 60.190990363404154, 0.0, 53.944719018854116, 50.85419149781486, 52.87698412698413, 53.377896613190735, nan, 61.14861111111111, 64.39393939393939, 63.11522633744856, 61.73453282828283, 34.957206174537674, 69.10310734463276, 6.890459363957597, 64.4743689825657, 31.32669983416252, 22.421875, 43.144350623240854, 0.0, 48.67450437989857, 1.6288951841359773, 0.007271669575334497, 76.77916666666667, 1.2411347517730498, 63.56944444444444, 11.195286195286196, 50.07086167800453, 49.51388888888889, 82.24702380952381, 46.19444444444444, 78.78066378066379, 11.050394656952033, 39.75342053826492, 33.78060263653484, 55.0414722654225, 44.414014953921054, 53.889573070607554, 18.78066378066378, 57.51934588991093, 58.55003940110323, 41.43184421534937, 80.03414544112218, 49.33933933933934, 70.65789473684211, 64.26470588235294, 47.816248019914006, 77.22855935783693, 92.42165242165242, 31.153039832285117, 0.2997601918465228, 71.89166666666667, 89.13333333333333, 78.02222222222223, 86.01666666666667, 56.576869942766926, 63.17471590909091, 87.45138888888889, 86.67514843087362, 53.11179277436946, 0.0, 59.22648312028843, 63.36048730368413, 7.974910394265233, 40.63977541371158, 56.201344656758664, 29.62638888888889, 71.39305555555555, 62.22404172731684, 61.263179237631796, 42.675544794188866, 58.42145593869732, 39.04794364917064, 79.0416008425487, 0.05533421868083222, 0.13997760358342665, 0.0, 58.055957549445246, 35.154941373534335, 44.57724656927844, 51.67568961072442, 86.07266435986159, 0.0, 56.970006816632576, 53.75354107648725, 43.2978432978433]
# 199 2

# %%
comm_partcptn = comm_ops

# %%
folder_path=Path('../../data/raw/workstation/')
files_go=glob.glob(str(folder_path/'tes_*_go.bz2'))
files_nc=glob.glob(str(folder_path/'tes_*_nc.bz2'))
# avg_data=comm_partcptn.compute_community_participation()
# reader.data_dump_pkl(f'raw/workstation/pca_results/pca_avg_mos', avg_data)

# %%
files_go[1].split('_')[-2]
# Out:
# 'enti'

# %%
itr=0
pts=algo_umap.compute_parameters(df_go[itr])
algo_umap.plot_transition(df_go[itr],pts['start_points'],pts['stop_points'])
# Out:
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\NSharma\anaconda3\envs\umap310\lib\site-packages\sklearn\utils\deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
comm_points=comm_ops.get_crossing_go(df_go[itr],pts)
# Out:
# this cell
# this cell

# %%
pts
# Out:
# {'start_points': [9100, 22700, 33200, 37100],
#  'stop_points': [10600, 28600, 33600, 37500]}

# %%
comm_points
# Out:
# {'start_comm': [9276, 23275, 33358, 37262],
#  'stop_comm': [9629, 27856, 34000, 37900]}

# %%
df_bm =comm_ops.get_binairized_matrix(df_nc.loc[itr].iloc[5000:10000],comm_points['start_comm'][1])

# %%
df_gc = comm_ops.get_community_percentage(comm_points['start_comm'][1],comm_points['stop_comm'][1],df_bm)

# %%
df_gc[]
# Out:
#             total  percentage
# community
# MO         112000   63.862500
# VIS        100000   56.578000
# ORB         68000   64.750000
# HTh         88000   48.769318
# OLF         72000   77.248611
# HIPP       100000   22.074000
# MID        140000   37.155714
# HIND       172000    3.707558

# %% [markdown]
# Check comm participation results

# %%
df = reader.data_read_pkl('results/calculate_final_params/final_fn.pkl')

# %%
df_comm = reader.data_read_bz2('results/comm_umap_results/pca_full_df_fn')

# %%
df_comm
# Out:
#             mo        vis        orb        hth        olf       hipp  \
# 0    68.000088  68.289409  76.014199  77.723354  80.547003  77.044335
# 1    72.338393  78.908000  81.452941  82.945455  82.798611  73.111000
# 2    65.899107  80.475000  87.427941  81.610227  95.141667  70.178000
# 3    75.963115  80.703825  81.567020  75.212370  82.797511  70.273224
# 4    45.982523  72.097187  74.938569  67.276990  76.387705  68.983802
# ..         ...        ...        ...        ...        ...        ...
# 206  47.984821  64.196000  68.369118  76.278409  88.213889  57.283000
# 207  57.094643  74.808000  79.323529  79.730682  86.670833  69.073000
# 208  71.994643  80.652000  77.858824  67.229545  85.304167  68.777000
# 209  77.634821  83.364000  78.450000  66.745455  88.237500  66.327000
# 210  75.865179  62.601000  86.517647  82.920455  91.658333  80.358000
#
#            mid       hind
# 0    64.737861   9.906633
# 1    70.641429   6.076163
# 2    58.357857   2.979651
# 3    65.167057   6.758165
# 4    50.084034   1.889411
# ..         ...        ...
# 206  35.007857   1.075000
# 207  57.862143   6.252326
# 208  60.397143  11.028488
# 209  59.627857  12.552907
# 210  56.377857   5.629651
#
# [211 rows x 8 columns]

# %%
df_old=reader.data_read_bz2('raw/workstation/pca_results/pca_part_df_fn')

# %%
df_old
# Out:
#             mo        vis        orb        hth        olf       hipp  \
# 0    28.272651  23.494163  31.143664   5.081948  45.294711   6.025940
# 1    47.791457  51.006608  66.821068  63.736484  83.299682  38.931718
# 2     6.654781   2.320786   2.921922   1.153102   3.800691   0.831424
# 3    23.705357  14.150000  31.535294  18.197727  51.719444   6.176000
# 4    40.879121  44.518343  44.984337  28.262507  36.867193  21.048521
# ..         ...        ...        ...        ...        ...        ...
# 445  17.977295  16.988399  24.757745   9.280742  51.675690   7.823666
# 446   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 447  22.682954  21.717791  30.250812  40.149191  56.970007  27.315951
# 448   7.896601   2.028329  16.380603  12.702807  53.753541   5.087819
# 449   4.839417  13.056511   9.228212   6.176011  43.297843  10.447174
#
#            mid      hind
# 0     6.864925  0.678672
# 1    35.926683  3.091384
# 2     2.396540  0.877327
# 3     4.920000  0.700000
# 4    25.142857  2.331086
# ..         ...       ...
# 445   3.695724  0.326445
# 446   0.000000  0.000000
# 447   8.126643  0.526109
# 448   0.384460  0.191053
# 449   0.793261  0.251414
#
# [450 rows x 8 columns]

# %%
reader.data_read_pkl('results/calculate_final_params/final_enti.pkl')[0]
# Out:
# {'n_part': 151,
#  'n_full': 57,
#  'n_total': 208,
#  'itr_tran': [0,
#   2,
#   3,
#   4,
#   5,
#   9,
#   12,
#   13,
#   16,
#   17,
#   18,
#   20,
#   21,
#   22,
#   25,
#   28,
#   29,
#   31,
#   33,
#   34,
#   35,
#   36,
#   40,
#   42,
#   43,
#   44,
#   45,
#   46,
#   47,
#   50,
#   53,
#   55,
#   56,
#   57,
#   58,
#   59,
#   60,
#   61,
#   62,
#   68,
#   73,
#   74,
#   75,
#   80,
#   81,
#   82,
#   83,
#   86,
#   87,
#   88,
#   91,
#   92,
#   93,
#   97,
#   99,
#   100,
#   103,
#   104,
#   105,
#   108,
#   111,
#   112,
#   114,
#   115,
#   118,
#   119,
#   120,
#   121,
#   125,
#   128,
#   129,
#   132,
#   133,
#   134,
#   135,
#   137,
#   138,
#   139,
#   141,
#   145,
#   148,
#   151,
#   152,
#   154,
#   155,
#   156,
#   158,
#   159,
#   161,
#   163,
#   165,
#   166,
#   167,
#   168,
#   170,
#   171,
#   172,
#   173,
#   174,
#   176,
#   177,
#   181,
#   183,
#   184,
#   185,
#   186,
#   187,
#   190,
#   191,
#   192,
#   195,
#   196,
#   198]}
